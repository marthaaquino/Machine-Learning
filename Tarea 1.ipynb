# %% [markdown]
# <div class="alert alert-info" role="alert">
#  <p class ="lead">
#  <h1>Machine Learning para físicos </h1>
#  <h2>Tarea 1 - Programación</h2>
#  <h3>Autor: Aquino Chapa Martha Abril<h3>
#  </div>

# %%
#Importamos las librerías que usaremos
import random
import numpy as np
import string

# %% [markdown]
# ### 1. Escribe una función que reciba una lista de números y determine si todos sus elementos son diferentes entre si.

# %%
def Lista_repeticion(lista):
    #Creamos un contador donde se sumará un 1 cada vez que se encuentre elementos repetidos.
    numero=0
    #Creamos un ciclo que pase por cada elemento de la lista
    for i in range(0,len(lista)):
        #tomamos un elemento i de la lista y lo vamos comparando con todos lo elementos de la lista
        for j in range(0,len(lista)):
            #si los elementos i y j son iguales, pero su indice es diferente (es decir no estamos contando el 
            #elemento con el que estamos comparando) sumamos un elemento al contador
            if lista[i]==lista[j] and i!=j:
                numero +=1
    #Si no se contarón elementos repetidos se imprime la leyenda "Todos los elementos son diferentes"
    if numero==0:
        print("Todos los elementos son diferentes.")
    #Si hay elementos repetidos se imprime: "Hay elementos repetidos"
    if numero!=0:
        print("Hay elementos repetidos.")

# %% [markdown]
# Probando la función:

# %%
Lista_repeticion([1,2,3,4,5])
# Out:
# Todos los elementos son diferentes.

# %%
Lista_repeticion([2,2,3,5,5])
#:) la función se comporta correctamente.
# Out:
# Hay elementos repetidos.

# %% [markdown]
# ### 2. Listas y diccionarios por comprensión.
#
# ### Escribe una función que reciba una cadena y regrese una lista que contenga sólo los caracteres numéricos incluidos en la cadena. Para este ejercicio debes usar listas por comprensión.

# %%
def cadena_numerica(cadena):
    #Creamos un arreglo donde cada entrada es un digito de la cadena
    numeros =[]
    #Creamos un ciclo que pase por todos los elementos de la cadena
    for i in cadena:
        #Si el elemento i es un digito se anexa al arreglo de números
        if i.isdigit()==True:
            numeros.append(i)
    return(numeros)

# %%
#Probamos la función
print(cadena_numerica("hola 026.8"))
print(cadena_numerica("Mi nombre es Martha y tengo 22 años, y es el año 2022 del mes 0,2"))
print(cadena_numerica("Prueba :)"))
#:) vemos que funciona correctamente la función
# Out:
# ['0', '2', '6', '8']
# ['2', '2', '2', '0', '2', '2', '0', '2']
# []

# %% [markdown]
# ### Escribe una función que reciba una cadena que almacena una oración y regrese un diccionario por comprensión que contenga cada palabra de la oración como llave y la longitud de dicha palabra como valor.

# %%
def cadena_diccionario(cadena):
    #Dividimos la cadena en palabras las cuales deben estar separadas por un espacio
    cadena_cortada=cadena.split()
    #Realizamos un ciclo el cual elimine los números de la horación y sólo deje las palabras
    for i in cadena_cortada:
        if i.isdigit():
            cadena_cortada.remove(i)
    #Cremos un diccionario el cual contiene una palabra de la oración como llave y su valor es la longitud de la palabra
    diccionario = {elemento : len(elemento) for elemento in cadena_cortada}
    return(diccionario)

# %%
print(cadena_diccionario("Hola me llamo Martha y tengo 22 años"))
# Out:
# {'Hola': 4, 'me': 2, 'llamo': 5, 'Martha': 6, 'y': 1, 'tengo': 5, 'años': 4}

# %%
print(cadena_diccionario("Hola me llamo Martha y tengo 22 años y nací el 29 de mayo del 99"))
# Out:
# {'Hola': 4, 'me': 2, 'llamo': 5, 'Martha': 6, 'y': 1, 'tengo': 5, 'años': 4, 'nací': 4, 'el': 2, 'de': 2, 'mayo': 4, 'del': 3}

# %% [markdown]
# ### 3. Escribe una función que reciba el archivo de texto temperaturas.txt, el cual contiene un conjunto de datos que representan temperaturas. La función deberá regresar un diccionario con los siguientes datos:
#
# - La temperatura máxima.
# - La temperatura mínima.
# - La temperatura promedio.
# - La mediana de las temperaturas.
#
# ### El diccionario resultado debe tener la siguiente forma: { ’maximo’: 35, ’minimo’:
# ### 15, ’promedio’: 25, ’mediana’: 28 }.
#
# Nota: Los valores mostrados son sólo ilustrativos, no necesariamente son los valores
# correctos.

# %%
#la función recibe el nombre del archivo como entrada
#el nombre debe ser de la forma "archivo_nombre.txt"
def temperaturas(archivo_nombre):
    
    #Abrimos el archivo
    DATOS = open(archivo_nombre)
    #Creamos un arreglo donde se acomodarán los elementos del archivo
    archivo = []
    #Cada elemento en el archivo lo convertimos a un flotante y lo anexamos al arreglo archivo
    for i in DATOS:
        archivo.append(float(i))
    
    #Máximo de la temperatura
    t_max=max(archivo)
    #Minimo
    t_min=min(archivo)
    #Obtenemos el promedio
    t_prom = sum(archivo)/len(archivo)
    
    #Calculamos la longitud de los datos y lo dividimos entre dos
    m =(len(archivo)/2)
    #Acomodamos los elementos de menor a mayor
    archivo_acomodado = sorted(archivo)
    #Si el archivo no es divisible entre dos
    if len(archivo) % 2 !=0:
        #que la mediana sea el elmento medio del arreglo acomodado
        mediana = archivo_acomodado[int(m)]
    #Si el archivo es divisible entre dos que la mediana se defina como
    else:
        mediana = (archivo_acomodado[int(m)-1]+archivo_acomodado[int(m)])/2
    #acomodamos el diccionario:
    diccionario = {"Maximo": t_max , "Minimo":t_min, "Promedio":t_prom,"Mediana": mediana }
    return diccionario

# %%
temperaturas("temperaturas.txt")
# Out:
# {'Maximo': 28.2,
#  'Minimo': 0.8,
#  'Promedio': 14.848309178743966,
#  'Mediana': 14.7}

# %% [markdown]
# ### 4. Implementa la fórmula de la desviación estándar en una función de Python:
#
# $$DE=\sqrt{\frac{\sum_{}^{} |x-\mu|^2}{N}}$$
#
# ### Donde:
#
# - x es un elemento del conjunto.
# - $\mu$ es la media del conjunto de datos.
# - $N$ es el número total de datos.
# - La función recibe una lista de datos numéricos y regresa la desviación estándar de los datos.

# %%
def desviacion_estandar(conjunto):
    #Primero calculamos la media
    media = sum(conjunto)/len(conjunto)
    #Creamos una variable donde almacenaremos la suma
    suma = 0
    #sumamos cada elemento en el conjunto de datos, le restamos la media y lo elevamos al cuadrado
    for i in conjunto:
        suma +=(i-media)**2
    #El valor de la desviación estándar
    desviacion = (suma/len(conjunto))**(1/2)
    return desviacion

# %%
#Comparando la lista con el valor dado a partir la función std de numpy
lista_prueba = [1,2,3,4,52,3,1,2,5,2,4]
print(desviacion_estandar(lista_prueba)-np.std(lista_prueba))
#La diferencia es 0, por lo que la función realizada corresponde con el valor dado por una función de python
# Out:
# 0.0

# %% [markdown]
# ### 5. El teorema del mono infinito afirma que si un mono presiona al azar teclas de un teclado de alguna computadora durante un tiempo infinito, en algún momento podrá escribir cualquier texto dado. El texto que trataremos de generar a partir de la simulación es el siguiente: "methinks it is like a weasel". La simulación se divide en tres pequeñas funciones:

# %% [markdown]
# ### Escribe una función que genere cadenas pseudoaleatorias de longitud igual a la longitud de la cadena dada.

# %%
def cadena_aleatoria(n):
    #Se deben anexar más caracteres
    caracteres_especiales = str('*/|+$%')
    #string.ascii_letter incluye las letras mayusculas y minusculas en el abecedario inglés
    #string.digits los digitos
    #string.punctuation  los carácteres especiales: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~.
    #string.whitespace espacio
    #string.printable los elementos que se puedan escrbir
    cadena=random.sample(string.printable, n)
    return ''.join(cadena)

# %%
#Probando la función
cadena_aleatoria(10)
# Out:
# '_R\tINsnO\rL'

# %% [markdown]
# - Escribe una función que cuente las coincidencias de caracteres entre la cadena generada y la cadena dada.

# %%
def contar_coincidencias(cadena_dada1,cadena_generada1):
    #Dividimos las cadenas en listas para comparar los elementos
    cadena_dada = list(cadena_dada1)
    cadena_generada = list(cadena_generada1)
    #Variable donde se guardan el número de coincidencia
    numero=0
    #realizamos un ciclo que compare el i-ésimo elemento de la cadena dada con el j-+esimo elemento
    #de la cadena generada
    for i in cadena_dada:
        for j in cadena_generada:
            #Si los elementos son iguales que sume un elemento al número de coincidencias
            if i==j:
                numero+=1
    #nos regrese el número de coincidencias
    return numero

# %%
#Probamos la función
print(contar_coincidencias("Adjicke2414*","ri'50967ooep"))
# Out:
# 2

# %%
print(contar_coincidencias("AAAAABB*","3+"))
# Out:
# 0

# %% [markdown]
# - Escribe una función que de forma iterativa obtenga una cadena pseudoaleatoria, calcule las coincidencias de caracteres y termine si la dicha coincidencia es completa, es decir si se generó la cadena esperada. Al final del ciclo iterativo debe imprimir el mayor número de coincidencias y la cadena que lo generó.

# %%
def contar_coincidencias_ordenadas(cadena_dada1,cadena_generada1):
     #Dividimos las cadenas en listas para comparar los elementos
    cadena_dada = list(cadena_dada1)
    cadena_generada = list(cadena_generada1)
    #Variable donde se guardan el número de coincidencia
    numero=0
    #realizamos un ciclo que compare el i-ésimo elemento de la cadena dada con el j-+esimo elemento
    #de la cadena generada
    for i in range(0,len(cadena_dada)):
        if cadena_dada[i]==cadena_generada[i]:
            numero+=1
    #nos regrese el número de coincidencias
    return numero

# %%
def generar_coincidencias(cadena_dada1,iteraciones =100):
    cadena_dada = str(cadena_dada1)
    #coincidencias = []
    #resultados = []
    conteo_iteraciones=1
    cadena_generada = str(cadena_aleatoria(len(cadena_dada)))
    coincidencias = contar_coincidencias_ordenadas(cadena_dada,cadena_generada)
    
    while coincidencias<len(cadena_dada):# or iteraciones >= conteo_iteraciones:
        print([coincidencias, cadena_generada])
        conteo_iteraciones +=1
        cadena_generada = str(cadena_aleatoria(len(cadena_dada)))
        coincidencias = contar_coincidencias_ordenadas(cadena_dada,cadena_generada)

    
        #return (coincidencias, cadena_generada1)
    else:
        return ([coincidencias, cadena_generada])
    
    #return (coincidencias,cadena_generada1)

# %%
len(str("8a"))
# Out:
# 2

# %%
generar_coincidencias("1")
# Out:
# [0, 'j']
# [1, '1']

# %%
generar_coincidencias("1a")
# Out:
# [0, 'F3']
# [0, 'u,']
# [0, '`C']
# [1, 'Ra']
# [0, '9U']
# [0, 'f\x0c']
# [0, '/n']
# [0, "'["]
# [0, 'G8']
# [0, '`m']
# [0, 'LP']
# [0, 'A#']
# [0, 'K|']
# [0, 'R?']
# [0, "6'"]
# [0, './']
# [0, 'kH']
# [0, 'an']
# [0, 'Oh']
# [0, 'fG']
# [0, '*V']
# [0, 'i\r']
# [0, '+X']
# [0, '\nl']
# [0, 'w&']
# [0, '#C']
# [0, "~'"]
# [0, 'MX']
# [0, 'DT']
# [0, '/V']
# [0, '|o']
# [0, '89']
# [0, 'bK']
# [0, 'lv']
# [0, 'N\t']
# [0, '}#']
# [0, 'pz']
# [0, 'sK']
# [0, '2Y']
# [0, '\\\n']
# [0, '?T']
# [0, '(y']
# [0, 'x\t']
# [0, '*>']
# [0, 'ZW']
# [0, ',m']
# [0, '*6']
# [0, 'W]']
# [0, 'v)']
# [0, 'yV']
# [0, '"B']
# [0, 'UT']
# [0, 'm|']
# [0, '~F']
# [0, '\n^']
# [0, ']$']
# [0, 'hU']
# [0, ';9']
# [0, '5d']
# [0, 'wk']
# [0, '4L']
# [0, 'ix']
# [0, '!\\']
# [0, 'w$']
# [0, '\t_']
# [0, 'F ']
# [0, '8A']
# [0, 'VL']
# [0, 'NJ']
# [0, 'Xg']
# [0, ';V']
# [0, '%|']
# [0, 'v<']
# [0, 'cY']
# [0, '5&']
# [0, '_r']
# [0, '`2']
# [0, ')W']
# [0, '{\r']
# [0, "\n'"]
# [0, 'Kw']
# [0, 'n\\']
# [0, 'M^']
# [0, 'BL']
# [0, ']c']
# [0, 'KJ']
# [0, 'IG']
# [0, '=@']
# [0, 'lt']
# [0, '\\z']
# [0, '8\r']
# [0, '*?']
# [0, '*C']
# [0, 'dX']
# [0, '!W']
# [0, '}h']
# [0, '\td']
# [0, 'Gw']
# [0, ":'"]
# [0, ';k']
# [0, 'NV']
# [0, 'xo']
# [1, ')a']
# [0, '/C']
# [0, "{'"]
# [0, 'lY']
# [0, 'E\\']
# [0, 'jf']
# [0, '?l']
# [0, '@v']
# [0, ')u']
# [0, 'y8']
# [0, '{v']
# [0, '0!']
# [0, '+(']
# [0, '7P']
# [0, 'f ']
# [0, '}5']
# [0, '@m']
# [0, '{S']
# [0, 'Mp']
# [0, 'MF']
# [0, '|o']
# [0, 'Up']
# [0, '&\x0c']
# [0, 'D6']
# [0, 'H"']
# [0, '\rz']
# [0, '<d']
# [0, '4y']
# [0, '3$']
# [0, 'r?']
# [0, '~D']
# [0, 'O)']
# [0, ':^']
# [0, '&y']
# [0, ')W']
# [0, '%>']
# [1, '#a']
# [0, '\x0cL']
# [0, 'Zv']
# [0, 'zA']
# [0, '_K']
# [0, '^1']
# [0, '$d']
# [0, '7]']
# [0, '.#']
# [0, 'Hp']
# [0, 'D)']
# [0, '(c']
# [0, '3[']
# [0, 'N,']
# [0, ':`']
# [0, '+\x0c']
# [0, "\n'"]
# [0, '|#']
# [0, 'Q6']
# [0, '[T']
# [0, '\x0ci']
# [0, 'A\n']
# [0, ',|']
# [0, '>&']
# [0, '4M']
# [0, '0[']
# [0, 'nN']
# [0, '6G']
# [0, 'tu']
# [0, '~"']
# [0, ':X']
# [0, 'w ']
# [0, 'Y.']
# [0, 'N)']
# [0, 'i7']
# [0, '=y']
# [0, 'jF']
# [0, '[s']
# [0, ' d']
# [0, 'rk']
# [0, 'a^']
# [0, '8%']
# [0, 'yX']
# [0, 'u`']
# [0, 'wB']
# [0, '^m']
# [0, 'L@']
# [0, '/C']
# [0, '@`']
# [0, '=W']
# [0, 'df']
# [0, '|s']
# [0, 'n+']
# [0, 'W/']
# [0, '`:']
# [0, 'a]']
# [0, 'MV']
# [0, 'hW']
# [0, 'aR']
# [0, ' 9']
# [0, 'p{']
# [0, 'Q\x0c']
# [0, ';_']
# [0, 'd\t']
# [0, '$Q']
# [0, 'JC']
# [0, 'aR']
# [0, '0!']
# [0, '~o']
# [0, 'og']
# [0, 'G^']
# [0, 'bw']
# [0, '@q']
# [0, 'Xz']
# [0, 'Y"']
# [0, '0#']
# [0, 'J;']
# [0, 'n%']
# [0, ' {']
# [0, 'h&']
# [0, '_T']
# [0, 'jF']
# [0, 'z@']
# [0, '\rD']
# [0, 'y-']
# [0, '/*']
# [0, 'i>']
# [0, 'PH']
# [0, 'R^']
# [0, 'AT']
# [0, 'bt']
# [0, 'p*']
# [0, 'c#']
# [0, '4Y']
# [0, '[G']
# [0, 'D\\']
# [0, 'QF']
# [0, 'ER']
# [0, 'SB']
# [0, '{^']
# [0, 'EB']
# [0, 'Ru']
# [0, '\t1']
# [0, '`w']
# [0, 'O"']
# [0, '-+']
# [0, 'zy']
# [0, 'q@']
# [0, 'fL']
# [0, 'B>']
# [0, 'd\\']
# [0, 'tQ']
# [0, '4I']
# [0, '.k']
# [0, '"6']
# [0, '@.']
# [0, '_l']
# [0, 'L(']
# [0, 'w0']
# [0, 'q}']
# [0, 'R]']
# [0, '!q']
# [0, 'QL']
# [0, '<W']
# [0, 'VB']
# [0, 'E+']
# [0, ';\x0c']
# [0, 'm&']
# [0, '*q']
# [0, 'sz']
# [0, '^,']
# [0, 'CY']
# [0, 'Wb']
# [0, 'r<']
# [0, '}Q']
# [0, '5]']
# [0, '2$']
# [0, '>)']
# [0, 'C2']
# [0, '\rB']
# [0, 'qg']
# [0, ' 6']
# [0, '"j']
# [0, 'S\t']
# [0, '5*']
# [0, 'F4']
# [0, '\tY']
# [0, '6J']
# [0, '@<']
# [0, '"T']
# [0, 'b!']
# [0, 'Q$']
# [0, '%!']
# [0, '2y']
# [0, 'e5']
# [0, 'W\n']
# [0, 'Z^']
# [0, '`@']
# [0, 'RJ']
# [0, 'v"']
# [0, 'TW']
# [0, 'P"']
# [0, '_n']
# [0, 'gv']
# [0, '=R']
# [0, 'W<']
# [0, 'ud']
# [0, 'RD']
# [0, 'Im']
# [0, '\t0']
# [0, 'kV']
# [0, '2<']
# [0, 'nu']
# [0, "'4"]
# [0, 'Pb']
# [0, 'xo']
# [0, '*#']
# [0, '\\q']
# [0, '!z']
# [0, '~X']
# [0, 'On']
# [0, 'iU']
# [0, 'vJ']
# [0, '[$']
# [0, 'K^']
# [0, ';E']
# [0, 'FE']
# [0, '=(']
# [0, 'kV']
# [0, 'G{']
# [0, 'l^']
# [0, '=h']
# [0, '>/']
# [0, '7\r']
# [0, 'U"']
# [0, 'Y(']
# [0, 'Dd']
# [0, 'rm']
# [0, 'mf']
# [0, '\\/']
# [0, ' 2']
# [0, 'f9']
# [0, 'MP']
# [0, 'j^']
# [0, 'MK']
# [0, 'Zw']
# [0, 'B5']
# [1, '18']
# [0, 'cn']
# [0, 'JD']
# [0, 'QP']
# [0, 's6']
# [0, 'zi']
# [0, 'Zf']
# [0, ';H']
# [0, '<7']
# [0, '/+']
# [0, '?7']
# [0, ':f']
# [0, 'zT']
# [0, 'Fc']
# [0, '\t^']
# [0, '/8']
# [0, '\x0b.']
# [0, '3j']
# [0, 'cK']
# [0, "i'"]
# [0, '{[']
# [0, '\r~']
# [0, 'Y ']
# [0, 'dc']
# [0, 'VP']
# [0, 'G=']
# [0, '/?']
# [0, 'j~']
# [0, 'a7']
# [0, '`m']
# [0, '6b']
# [0, '6;']
# [0, 'o_']
# [0, 'yD']
# [0, ')#']
# [0, 'rQ']
# [0, 'dm']
# [0, 'b<']
# [0, '\\,']
# [0, ';u']
# [0, '^;']
# [0, '2H']
# [0, '%"']
# [1, '18']
# [0, 'wl']
# [0, '|V']
# [0, 'cG']
# [0, 'z?']
# [0, '4#']
# [0, '2]']
# [0, 'AW']
# [0, '`#']
# [0, 'dX']
# [0, '|-']
# [0, 'DS']
# [0, 'I@']
# [0, '\\<']
# [0, '9v']
# [0, '~B']
# [0, '_U']
# [0, ']/']
# [1, '1q']
# [0, 'Xn']
# [0, '5W']
# [0, '"W']
# [0, '^}']
# [0, '&E']
# [0, '\x0b#']
# [0, 'f*']
# [0, ')(']
# [0, '\x0b<']
# [0, "'g"]
# [0, 'BU']
# [1, 'Ra']
# [0, 'tK']
# [0, ',)']
# [0, 'Xe']
# [0, 'tD']
# [0, 'W2']
# [0, '#V']
# [0, '4O']
# [0, '\x0bd']
# [0, '~"']
# [0, '\np']
# [0, 'X)']
# [0, '(D']
# [0, '{l']
# [0, 'JB']
# [0, '=\t']
# [0, 'Sq']
# [0, 'TY']
# [0, '@(']
# [0, 'Z9']
# [0, 'KZ']
# [0, '/H']
# [0, '<p']
# [0, '$[']
# [0, 'WN']
# [0, 'k.']
# [0, '7o']
# [0, 'mp']
# [0, '\r4']
# [0, ')w']
# [0, 'AI']
# [0, '(:']
# [0, 'b(']
# [0, '.(']
# [0, 'V8']
# [0, "'!"]
# [0, '(:']
# [0, '(M']
# [0, '?z']
# [0, 'S%']
# [0, 'hp']
# [0, 'ZP']
# [0, '&m']
# [0, '\n+']
# [0, '6+']
# [0, 'H!']
# [0, 'MI']
# [0, 'oK']
# [0, '"J']
# [0, 'F2']
# [0, 'JH']
# [0, 'C"']
# [0, 'k[']
# [0, 'K=']
# [0, 'H7']
# [0, '6`']
# [0, 'iQ']
# [0, '(w']
# [0, 'wN']
# [0, '3G']
# [0, 'wD']
# [0, ' M']
# [0, 'C\r']
# [0, 'K+']
# [0, 'XS']
# [0, 'mi']
# [1, ' a']
# [0, '^y']
# [0, '"u']
# [0, 'Az']
# [0, '7]']
# [0, 'DX']
# [0, 'H;']
# [0, '[G']
# [0, '0U']
# [0, ')r']
# [0, 'v5']
# [0, '\tE']
# [0, 'b.']
# [0, 'y1']
# [0, '9~']
# [0, '*?']
# [0, 'C>']
# [0, '6]']
# [0, '_;']
# [0, '<A']
# [0, '`m']
# [0, 'cA']
# [0, 'h^']
# [0, 'A0']
# [0, 'sN']
# [0, '8Q']
# [0, 'GJ']
# [0, '>j']
# [0, 'G!']
# [0, '\t>']
# [1, '16']
# [0, 'lJ']
# [0, '{6']
# [1, '1A']
# [0, 'HG']
# [0, 'n3']
# [0, '9^']
# [0, '|[']
# [0, '34']
# [0, 'uK']
# [0, 'rp']
# [0, 'tr']
# [0, 'A+']
# [0, 'Eg']
# [0, 'hO']
# [0, 'q\\']
# [0, 's!']
# [0, '/k']
# [0, 'z\x0b']
# [0, ')r']
# [0, ':v']
# [0, "^'"]
# [0, '[}']
# [0, 'Fr']
# [0, '[c']
# [0, 'Az']
# [0, '>,']
# [0, '^1']
# [0, '8q']
# [0, 'Dq']
# [0, '\n]']
# [0, '\n^']
# [0, '+6']
# [0, 'o,']
# [0, '_e']
# [0, '8B']
# [0, 'Ql']
# [0, "K'"]
# [0, '(#']
# [0, '!#']
# [0, 'zx']
# [0, 'P9']
# [0, '|.']
# [0, 'S\\']
# [0, 'M)']
# [0, 'TY']
# [0, 'G-']
# [0, 'tw']
# [0, '|Q']
# [0, '$o']
# [0, 'Ef']
# [0, 'HP']
# [0, '\x0bZ']
# [0, 'J0']
# [0, '\x0c!']
# [1, '1.']
# [0, 'P!']
# [0, '@3']
# [0, 'I{']
# [0, '\\8']
# [0, '5|']
# [0, 'YI']
# [0, '\ri']
# [0, 'j-']
# [0, 'qc']
# [0, ';E']
# [0, 'QH']
# [0, '3c']
# [0, 'yF']
# [0, 'y_']
# [0, 'S-']
# [0, '~{']
# [0, '`4']
# [0, '=c']
# [0, '-2']
# [0, '&i']
# [0, '$D']
# [0, '2/']
# [0, 'X)']
# [0, 'XC']
# [0, 'PE']
# [0, '.|']
# [0, 'ay']
# [0, '2n']
# [0, '\\0']
# [0, '<i']
# [1, '1J']
# [0, '\x0co']
# [0, '\\=']
# [1, 'ba']
# [0, '?I']
# [0, '\t]']
# [0, '%>']
# [0, 'b1']
# [0, '0i']
# [0, '73']
# [0, 'j`']
# [0, 'f[']
# [0, 'H~']
# [0, 'XG']
# [0, '-Y']
# [0, 'X)']
# [0, 'GA']
# [0, '[e']
# [0, 'O\t']
# [0, '\x0b;']
# [0, 'X%']
# [0, '.e']
# [0, 'C>']
# [0, 'mT']
# [0, '3H']
# [0, '>?']
# [0, 'Rk']
# [0, ':w']
# [0, 'WP']
# [0, '*}']
# [0, 'o{']
# [0, '$)']
# [0, '[H']
# [1, 'pa']
# [0, 'QK']
# [0, 'X*']
# [0, '}1']
# [0, '7!']
# [0, 'k[']
# [0, 'V;']
# [0, '6\x0c']
# [0, 'IA']
# [0, '*f']
# [0, 'gH']
# [0, '#9']
# [0, 'P1']
# [0, 'MY']
# [0, '3o']
# [0, 'S4']
# [0, ']!']
# [0, 'f,']
# [0, 'V;']
# [0, '4d']
# [0, 'Dn']
# [0, '?}']
# [0, '\x0b=']
# [0, 'ER']
# [0, 'X}']
# [0, ']/']
# [0, '<9']
# [0, 'YS']
# [0, '\x0br']
# [0, 'o<']
# [1, '1`']
# [0, 'qU']
# [0, 'j?']
# [0, '~C']
# [1, 'ca']
# [0, 'mz']
# [0, '\x0c]']
# [0, '~T']
# [0, '0#']
# [0, '>+']
# [0, '}X']
# [0, 'wI']
# [1, '1b']
# [0, '/+']
# [0, 'Oh']
# [0, '}X']
# [0, '`N']
# [0, 'Y\n']
# [0, ':<']
# [0, '~-']
# [0, '\rE']
# [0, ';(']
# [0, '{\x0c']
# [0, '8 ']
# [0, 'o`']
# [0, 'w4']
# [0, 'e\x0c']
# [0, '+w']
# [0, 'mu']
# [0, 'u`']
# [0, '%v']
# [0, '#C']
# [0, 'qO']
# [0, 'cD']
# [0, 'P0']
# [0, 'e+']
# [0, '*J']
# [0, 'Ww']
# [0, 'D&']
# [0, '~{']
# [0, 'Q)']
# [0, "k'"]
# [0, 'Gk']
# [0, 'f\\']
# [0, ',m']
# [0, 'n?']
# [0, '\r^']
# [0, '@v']
# [0, '6^']
# [1, '1?']
# [0, 'Ms']
# [0, 'cu']
# [0, '0;']
# [0, '}>']
# [0, 'l9']
# [0, '$K']
# [0, '?{']
# [0, '56']
# [0, 'D{']
# [0, '|b']
# [0, ' @']
# [0, 'E?']
# [0, '"F']
# [0, '\x0bQ']
# [0, 'y(']
# [1, '6a']
# [0, 'IZ']
# [0, 'H]']
# [0, 'tS']
# [0, '$Z']
# [0, '2w']
# [0, '|Q']
# [0, 'S-']
# [0, '(A']
# [0, 'bm']
# [0, '|9']
# [1, '1|']
# [0, '@q']
# [0, 'm\x0b']
# [0, '|Z']
# [0, '/`']
# [0, 'IS']
# [0, 'T@']
# [1, 'Ua']
# [0, 'yH']
# [0, 'os']
# [0, 'oc']
# [0, ',o']
# [1, '1.']
# [0, '~{']
# [0, 'xV']
# [0, 'q`']
# [0, '"<']
# [0, 'w1']
# [1, 'qa']
# [0, 'ue']
# [0, 'm^']
# [0, '>Y']
# [0, ':"']
# [0, '@\x0b']
# [0, '%;']
# [0, '7d']
# [0, 'CT']
# [0, ' "']
# [0, 'Mw']
# [0, '0V']
# [0, '_j']
# [0, 'jk']
# [0, 'Yl']
# [0, '\r=']
# [0, 'h2']
# [0, 'Ve']
# [0, 'E{']
# [0, 'zs']
# [0, 'f&']
# [0, '92']
# [0, 'V#']
# [0, 'M?']
# [0, 'NH']
# [0, 'wh']
# [0, 'db']
# [0, '}g']
# [0, '}A']
# [0, '+|']
# [0, ',k']
# [0, '<k']
# [0, '5#']
# [0, 'A&']
# [0, 'v?']
# [0, 't*']
# [0, '9L']
# [0, 's:']
# [0, 'Z;']
# [1, '1G']
# [0, '96']
# [0, 'p5']
# [0, '\\n']
# [0, 'YL']
# [0, 'D?']
# [0, 'bl']
# [0, '9x']
# [0, '7U']
# [0, '?F']
# [0, '[Y']
# [0, 'r6']
# [0, 'M5']
# [0, ':P']
# [0, '8D']
# [0, '30']
# [0, 'a#']
# [0, '<9']
# [0, '\ne']
# [0, 'Ux']
# [0, '\r.']
# [0, ':Y']
# [0, '5x']
# [0, 'OZ']
# [0, 'p\r']
# [0, 'c@']
# [0, 'Pv']
# [0, 'V?']
# [0, '5/']
# [0, '9H']
# [0, 'b{']
# [0, '0$']
# [0, 'p{']
# [0, 'Z:']
# [0, '&.']
# [0, 'D$']
# [0, 'R!']
# [0, 'F=']
# [0, 'IX']
# [0, 'N$']
# [0, 'M1']
# [1, '2a']
# [0, 'IO']
# [0, 'nd']
# [0, 'W\x0c']
# [0, '(1']
# [0, '(L']
# [0, 'N)']
# [0, 'd~']
# [0, 'U/']
# [0, 'b=']
# [0, '3m']
# [0, 'lM']
# [0, ',R']
# [0, 'U_']
# [0, 'xG']
# [0, 'l)']
# [0, 'Jt']
# [0, '[F']
# [0, '.p']
# [0, ',b']
# [0, ')K']
# [0, 'h?']
# [0, '\x0cQ']
# [0, 'Hm']
# [0, '#f']
# [0, 'r@']
# [0, '(#']
# [0, '7w']
# [0, ' M']
# [0, '\x0c&']
# [0, '$@']
# [0, 'gx']
# [1, '1g']
# [0, '?;']
# [0, '$j']
# [0, '> ']
# [0, 'uC']
# [0, 'Xl']
# [0, 'L7']
# [0, '{5']
# [0, "f'"]
# [0, 'Y{']
# [0, 'm>']
# [0, 'L!']
# [0, 'jm']
# [0, '%6']
# [0, 'DW']
# [0, '\tJ']
# [0, ':S']
# [0, 'Wl']
# [0, 'Jy']
# [0, '|\x0b']
# [0, 'I-']
# [0, 'W,']
# [0, 'XG']
# [0, 't4']
# [0, '\tG']
# [0, 'y=']
# [0, '{N']
# [0, 'E\\']
# [0, '"\x0c']
# [0, 'VH']
# [0, 'C]']
# [0, 'p3']
# [0, '/2']
# [0, 'ck']
# [0, '{P']
# [0, 'Ce']
# [0, 'u$']
# [0, 'D+']
# [0, '\r&']
# [0, '#g']
# [0, ';]']
# [0, '<|']
# [0, 'Q*']
# [0, 'px']
# [0, '4F']
# [0, 'dG']
# [0, '\\E']
# [0, '5q']
# [0, 'L8']
# [0, 'O#']
# [0, 'jt']
# [0, 'TB']
# [0, '4%']
# [0, '#y']
# [0, "}'"]
# [0, 'x`']
# [0, '\x0b-']
# [0, 'wE']
# [0, 'cS']
# [0, 'P+']
# [0, 'X"']
# [0, 'Hk']
# [0, '{b']
# [0, '6T']
# [0, '\\F']
# [0, 'Oh']
# [0, '`v']
# [0, '3Y']
# [0, ';`']
# [0, '0V']
# [0, '?d']
# [0, 'hU']
# [0, ';>']
# [0, 'QR']
# [0, 'u?']
# [0, 'o>']
# [0, 'r\x0b']
# [0, 'Uh']
# [0, 'SB']
# [0, 'rO']
# [0, ':q']
# [0, '8b']
# [0, 'ny']
# [0, ']:']
# [0, '\nB']
# [0, 'pP']
# [0, 'eR']
# [0, ']I']
# [0, 'fY']
# [0, '"4']
# [0, '_<']
# [0, '{~']
# [0, 'R\x0c']
# [0, '?_']
# [0, 'B]']
# [0, 'uS']
# [0, "'6"]
# [0, 'It']
# [0, 'NP']
# [0, 'j[']
# [0, '!4']
# [0, 'T\t']
# [0, "'y"]
# [0, '=d']
# [0, 'Z(']
# [0, 'Xp']
# [0, ' \n']
# [0, 'q,']
# [0, 'jI']
# [0, '^+']
# [0, '3W']
# [0, "'M"]
# [0, "':"]
# [0, '}A']
# [0, 'H7']
# [0, '5{']
# [0, 'ar']
# [0, '\\.']
# [0, '3Y']
# [0, 'si']
# [0, '!g']
# [0, '!L']
# [0, 'D\x0c']
# [0, '>L']
# [0, 'kj']
# [0, '`6']
# [0, 'WH']
# [0, '2!']
# [0, 'ug']
# [0, 'BQ']
# [0, 'yl']
# [0, '\x0cv']
# [0, ':K']
# [0, 'z$']
# [0, 'L`']
# [0, '+L']
# [0, 'l$']
# [0, '\n6']
# [0, 'zs']
# [0, 'a}']
# [0, '@g']
# [0, 'ub']
# [0, 'CS']
# [0, '#~']
# [0, 'v2']
# [0, 'ZB']
# [0, 'L\\']
# [0, 'r=']
# [0, 'xZ']
# [0, '<p']
# [0, 'wR']
# [0, 'lZ']
# [0, '?q']
# [0, ':q']
# [0, ' 1']
# [0, 'R7']
# [0, '^_']
# [0, 'SO']
# [0, '>y']
# [0, 'J0']
# [0, 'u3']
# [0, 'zk']
# [0, '\t`']
# [0, 'ph']
# [0, '\x0b:']
# [0, '!#']
# [0, '0\r']
# [0, ' `']
# [0, 'PX']
# [0, 'p,']
# [0, 'Ut']
# [0, 'B\t']
# [0, 'dQ']
# [0, 'Hm']
# [0, 'Qf']
# [0, '[P']
# [1, '[a']
# [0, '6)']
# [0, '?5']
# [0, '\x0c\r']
# [0, 'eL']
# [0, 'QT']
# [0, '}R']
# [0, '|t']
# [0, '[H']
# [0, '\nU']
# [0, 'b[']
# [0, '!Q']
# [0, '.H']
# [0, 'CX']
# [0, 'SD']
# [0, '\tv']
# [0, '=k']
# [0, '3[']
# [0, 't+']
# [0, 'IP']
# [0, '`n']
# [0, '?>']
# [1, '3a']
# [0, '0G']
# [0, '4^']
# [0, '|s']
# [0, 'A>']
# [0, 'Al']
# [0, 'S_']
# [0, 'g!']
# [0, 'n.']
# [0, 'Qs']
# [0, '=C']
# [0, 'vE']
# [0, 'Pn']
# [0, 'Ue']
# [0, '/Q']
# [0, '0E']
# [0, 'nf']
# [0, '_g']
# [0, 'K8']
# [0, ';Y']
# [0, ':O']
# [0, '|+']
# [0, 'gB']
# [0, 'Wg']
# [0, 'Hp']
# [0, 'rl']
# [0, '@3']
# [0, 'Jq']
# [0, 'n\r']
# [0, 'L>']
# [0, 'pN']
# [0, 'n%']
# [0, 'rb']
# [0, '-W']
# [0, 'yh']
# [0, '\tD']
# [0, '"(']
# [0, 'nM']
# [0, '9^']
# [0, '(>']
# [0, '|\\']
# [0, 'pc']
# [0, 't4']
# [0, 'R\r']
# [0, '%i']
# [0, 'SV']
# [0, 'L~']
# [0, '"t']
# [0, '$z']
# [0, '^"']
# [0, 'f-']
# [0, 'n\t']
# [1, '1 ']
# [0, 'DU']
# [0, '5|']
# [0, ',t']
# [0, '7z']
# [0, '.v']
# [0, 'Z$']
# [0, '\x0bI']
# [0, 'cM']
# [0, 'j.']
# [0, 'VT']
# [0, 'tH']
# [0, '@T']
# [0, 'Qr']
# [0, ',h']
# [0, 'Vb']
# [0, '^(']
# [0, 'u,']
# [0, 'FS']
# [0, ')h']
# [0, '#G']
# [0, 'R)']
# [0, 'sC']
# [0, '~D']
# [0, 'c?']
# [0, '!j']
# [0, '&`']
# [0, 'Jr']
# [0, '[^']
# [0, 'U)']
# [0, 'Y ']
# [0, 'Vq']
# [0, '?g']
# [0, 'S-']
# [0, ':R']
# [0, '7.']
# [0, 'oJ']
# [0, 'OR']
# [0, 'uH']
# [0, '$z']
# [0, 'Eg']
# [0, 't ']
# [0, 'vI']
# [0, 'bz']
# [0, 'ho']
# [0, '+l']
# [0, '\nk']
# [0, '0m']
# [0, '2I']
# [0, '8o']
# [0, 'Ll']
# [0, 'J\n']
# [0, 'd7']
# [0, '9e']
# [0, '^\n']
# [0, '\t2']
# [0, 'P<']
# [0, '7y']
# [1, 'ja']
# [1, '1Z']
# [0, '"/']
# [0, 'K[']
# [0, '02']
# [0, 'uo']
# [0, '>d']
# [0, 'f?']
# [0, 'U=']
# [0, 'a?']
# [0, 'AF']
# [0, 'hN']
# [0, 'EZ']
# [0, 'ZQ']
# [0, 'PK']
# [0, 'vQ']
# [0, 'E?']
# [0, '0o']
# [0, ']7']
# [0, 'g%']
# [0, '\t~']
# [0, 'qJ']
# [0, '8Z']
# [0, '"\t']
# [0, '|x']
# [0, '@Z']
# [0, 'P)']
# [0, 'o+']
# [0, 'j1']
# [1, '1R']
# [0, 'L2']
# [0, 'oA']
# [0, '\x0bk']
# [0, 'u\\']
# [0, 'p\t']
# [0, 'A`']
# [0, 'L3']
# [0, '}?']
# [0, 'tZ']
# [0, '6o']
# [0, '(s']
# [0, 'vd']
# [0, '[J']
# [0, '\nK']
# [0, ':g']
# [0, 'nB']
# [0, 'u3']
# [0, "'o"]
# [0, 'S+']
# [0, '7o']
# [0, ';2']
# [0, 'zb']
# [0, '(S']
# [0, '(@']
# [0, '8A']
# [0, '^{']
# [0, 'Vm']
# [0, ':{']
# [0, 'SJ']
# [0, '!K']
# [0, 'K?']
# [0, 'mV']
# [0, '+.']
# [0, '_d']
# [0, '$;']
# [0, 't.']
# [1, '1=']
# [0, 'e)']
# [0, '}X']
# [0, 'wv']
# [0, 'W3']
# [0, '^{']
# [0, ',%']
# [0, '}!']
# [0, 'te']
# [0, '\x0c`']
# [0, '&-']
# [0, 'V&']
# [0, 'f:']
# [0, '^x']
# [0, '5.']
# [0, '5;']
# [0, 'kv']
# [0, '3]']
# [0, '3 ']
# [0, 'KR']
# [0, 'Jg']
# [0, '=f']
# [0, 'aP']
# [0, '/4']
# [0, 'M_']
# [0, 'u*']
# [0, 'bL']
# [0, '\nl']
# [0, '6?']
# [0, ':"']
# [0, 'C&']
# [0, "i'"]
# [0, 'b1']
# [0, '\\g']
# [0, 'D,']
# [0, '(p']
# [0, 'lX']
# [0, 'Rn']
# [0, ':6']
# [0, 'W1']
# [0, '7=']
# [0, 'Fc']
# [0, ']}']
# [0, 'I\x0c']
# [0, 'FW']
# [0, 'C8']
# [0, '*~']
# [0, '=i']
# [0, 'tR']
# [0, '>|']
# [0, 'eb']
# [0, '.x']
# [0, 'J\n']
# [0, ',f']
# [0, '(t']
# [1, 'ya']
# [0, 'n:']
# [0, '}:']
# [0, '3l']
# [0, 'nz']
# [0, 'Nm']
# [0, '<"']
# [0, '~@']
# [0, '`m']
# [0, '[T']
# [0, '-N']
# [0, '!g']
# [0, '4V']
# [0, 'Ll']
# [0, '<5']
# [0, 'T(']
# [0, '#r']
# [0, 'kj']
# [0, '\tE']
# [0, '*_']
# [0, '>|']
# [0, '*V']
# [0, 'Kt']
# [0, 'UM']
# [0, 'U ']
# [0, 'x.']
# [0, 'K ']
# [0, ')}']
# [0, 'b&']
# [0, '\x0b&']
# [0, ';H']
# [0, 'TE']
# [0, 'e\x0c']
# [0, '.4']
# [0, 'H*']
# [0, 'bU']
# [0, 'N7']
# [0, '\x0cA']
# [0, 'C}']
# [0, 'UK']
# [0, '/U']
# [0, 't\r']
# [0, '+R']
# [0, 'rQ']
# [0, '/v']
# [0, '.b']
# [0, 'X?']
# [0, '/3']
# [0, 'a8']
# [0, '%U']
# [0, '[w']
# [0, 'yY']
# [0, '$k']
# [0, 'X=']
# [0, '<*']
# [0, 'f+']
# [0, '5\x0b']
# [0, '(t']
# [0, 'c}']
# [0, '7J']
# [0, 'Re']
# [0, 'yD']
# [0, 'Qj']
# [0, 'pX']
# [0, 'a<']
# [0, 'n4']
# [0, '0@']
# [0, 'GR']
# [0, '[T']
# [0, 'r2']
# [0, '?-']
# [0, 'gn']
# [0, '@_']
# [0, 'pd']
# [0, ':m']
# [0, '2i']
# [0, 'f\x0b']
# [0, 'n)']
# [0, '9+']
# [0, '>5']
# [1, 'ba']
# [0, 'uU']
# [0, 'q2']
# [0, '>;']
# [0, '^d']
# [0, 'L{']
# [0, 'GD']
# [0, 'Ir']
# [0, 'lw']
# [0, 'Ew']
# [0, '/F']
# [0, '35']
# [0, '0S']
# [0, 'a8']
# [0, '"[']
# [0, "'<"]
# [0, 'D\t']
# [0, '\\|']
# [0, 'SU']
# [0, '7,']
# [0, '0R']
# [0, 'B\t']
# [0, '>Y']
# [0, 'Ch']
# [0, '[t']
# [0, '/%']
# [0, 'MI']
# [0, 'vs']
# [0, 'X{']
# [0, 'Ju']
# [0, 'ik']
# [0, '}n']
# [0, '=/']
# [0, 'J{']
# [0, '!&']
# [0, ']H']
# [0, 'aK']
# [0, 'HX']
# [0, 'Oq']
# [0, '<!']
# [0, '*?']
# [0, '3q']
# [0, '#s']
# [0, 'O.']
# [0, ' Q']
# [0, '6L']
# [0, 'm:']
# [0, '9"']
# [0, '%=']
# [0, '7f']
# [0, 'm[']
# [0, 'IE']
# [0, '$k']
# [0, 'k\t']
# [0, 'u/']
# [0, 'xU']
# [0, 'q-']
# [0, 'Bc']
# [0, '(8']
# [0, '&>']
# [0, 'xc']
# [0, 'gb']
# [1, '1v']
# [0, '/A']
# [0, '2]']
# [0, '\x0cU']
# [0, '&"']
# [0, 'B/']
# [0, 'IA']
# [0, "'w"]
# [0, '%.']
# [0, 'C3']
# [0, 'vx']
# [0, 'GQ']
# [0, '5}']
# [0, '<B']
# [0, 'J\x0c']
# [0, '%\x0c']
# [0, '0K']
# [0, 'j8']
# [0, 'pc']
# [0, 'cp']
# [0, 'l&']
# [0, '!J']
# [0, 'RU']
# [0, 'd{']
# [0, '3`']
# [0, '8w']
# [0, '@6']
# [0, '^N']
# [0, ':,']
# [0, 'eM']
# [0, 'Es']
# [0, '25']
# [0, '8C']
# [0, 'm*']
# [0, 'hy']
# [0, 'Gc']
# [0, '",']
# [0, 'bK']
# [0, '9!']
# [0, 'Yf']
# [0, '8h']
# [0, "K'"]
# [0, 'Ht']
# [0, '4>']
# [0, 'h;']
# [0, 'gM']
# [0, '$h']
# [0, '.c']
# [0, 'iG']
# [0, 'u`']
# [0, '5%']
# [0, 'ZG']
# [0, '`-']
# [0, ':]']
# [0, 'V2']
# [0, '`{']
# [0, 'IZ']
# [0, '|~']
# [0, '4$']
# [0, "'\r"]
# [0, 'X\x0b']
# [0, 'IV']
# [0, 'ts']
# [0, '\\v']
# [0, ' #']
# [0, 'YX']
# [0, '\td']
# [0, 'Bx']
# [0, '|q']
# [0, 'vL']
# [0, 'RG']
# [0, 'j7']
# [0, '81']
# [0, 'Z4']
# [0, '#W']
# [1, '.a']
# [0, '\x0c\n']
# [0, 'H2']
# [0, '!3']
# [0, 'o6']
# [0, 'nR']
# [0, '^<']
# [0, 'q ']
# [0, '\r3']
# [0, '\x0c:']
# [0, '8_']
# [0, 'k_']
# [0, '`[']
# [0, 'UL']
# [0, 'J1']
# [0, "G'"]
# [0, 'Qu']
# [0, '/F']
# [1, 'pa']
# [0, '{U']
# [0, 'Ks']
# [0, '+9']
# [1, '1=']
# [0, '2Q']
# [0, '>2']
# [0, 'kn']
# [0, 'gU']
# [0, 'R[']
# [0, '.@']
# [0, '< ']
# [1, '1n']
# [0, '@%']
# [0, '_:']
# [0, '5*']
# [0, '\t_']
# [0, '*)']
# [0, 'ry']
# [0, 'Lx']
# [0, 'o\n']
# [0, '|B']
# [0, 'gr']
# [0, '$v']
# [0, "D'"]
# [0, 'ou']
# [0, 'Y!']
# [0, 'OC']
# [0, 'KI']
# [0, '_~']
# [0, '>t']
# [0, 'Fd']
# [0, '`V']
# [0, '_V']
# [0, 'pF']
# [0, ';f']
# [0, 'mH']
# [0, 'V^']
# [0, 'c?']
# [0, '_$']
# [0, ',-']
# [0, 'H~']
# [0, 'y6']
# [0, '[e']
# [0, 'eY']
# [0, 'er']
# [0, '\x0cB']
# [0, 'OB']
# [0, 'wF']
# [0, 'a1']
# [0, "J'"]
# [0, 'gd']
# [0, 'wj']
# [0, 'T0']
# [0, '(Y']
# [0, '\x0bi']
# [0, 'EA']
# [0, 'K_']
# [0, '?|']
# [0, 'aC']
# [0, ' `']
# [0, 'H%']
# [0, 'mD']
# [0, 'z4']
# [0, 'k{']
# [0, '#v']
# [0, '=m']
# [0, 'M2']
# [0, '4F']
# [0, '#7']
# [0, 'w_']
# [0, '-q']
# [0, '\nQ']
# [0, "f'"]
# [0, '0Y']
# [0, 'Zv']
# [0, '<0']
# [0, '8B']
# [0, 'UV']
# [0, "'G"]
# [0, ']t']
# [0, '5\n']
# [0, '!j']
# [0, 'Ko']
# [0, 'y[']
# [0, 'xJ']
# [0, 'Km']
# [0, '\x0b^']
# [0, 'cH']
# [0, 'I`']
# [0, 'hA']
# [0, ':]']
# [0, 'qT']
# [0, '~E']
# [0, ':(']
# [0, 'VU']
# [0, '5?']
# [0, '+)']
# [0, 'ZX']
# [0, 'zM']
# [0, ']0']
# [0, '9Z']
# [0, 'i%']
# [0, 'Af']
# [0, '+"']
# [0, 'N=']
# [0, '7N']
# [0, 'Yz']
# [0, ',@']
# [0, '<:']
# [0, '!Y']
# [0, ',7']
# [0, '/9']
# [0, ')H']
# [0, 'rJ']
# [1, '1I']
# [0, '`!']
# [0, '*v']
# [0, ':P']
# [0, '_ ']
# [0, 'd4']
# [0, '"L']
# [0, 'os']
# [0, 'v=']
# [0, 'M|']
# [0, 'jM']
# [0, '\r2']
# [0, '\tU']
# [0, 'l6']
# [0, "'z"]
# [0, 'vF']
# [0, '{l']
# [0, ']~']
# [0, 'lT']
# [0, ',/']
# [0, 'Q$']
# [0, '+M']
# [0, 'Gc']
# [0, 'QK']
# [0, 'Y%']
# [0, 'r\r']
# [0, '\\j']
# [0, '^z']
# [0, '`7']
# [0, 'ni']
# [0, 'J`']
# [0, 'J#']
# [0, 'H+']
# [0, '\r\\']
# [0, 'Gf']
# [0, '$~']
# [0, '3J']
# [0, 'Gu']
# [0, 'ms']
# [0, '#c']
# [0, '?9']
# [0, 'H2']
# [0, '\x0bA']
# [0, 'R@']
# [0, '0\r']
# [0, '*k']
# [0, 'jU']
# [0, 'F_']
# [0, 'Eq']
# [0, '{>']
# [0, 'B|']
# [0, '\x0b:']
# [0, '+C']
# [0, 'x\n']
# [0, '6*']
# [0, '}3']
# [0, '} ']
# [0, 'Dp']
# [0, 'k^']
# [0, 'EU']
# [0, '=\x0b']
# [0, 'tr']
# [0, 'w~']
# [0, '2e']
# [0, '<?']
# [0, 'U#']
# [0, 'uF']
# [0, 'Wv']
# [0, 'S@']
# [0, 'r\n']
# [0, 'R.']
# [0, ',(']
# [0, 'ND']
# [0, '0;']
# [0, '\rG']
# [0, '%\t']
# [0, '_/']
# [0, 'Dm']
# [0, ' 6']
# [0, '/J']
# [0, 'rZ']
# [0, 'sl']
# [0, ':1']
# [0, 'N\r']
# [0, 'R\n']
# [0, '#(']
# [0, ']-']
# [0, '4$']
# [0, 'c}']
# [0, '=K']
# [0, "'r"]
# [0, 'mq']
# [0, '3?']
# [0, 'A ']
# [0, '#9']
# [0, '}c']
# [0, ')D']
# [0, '*`']
# [0, '[c']
# [0, 'NU']
# [1, 'ja']
# [0, 'v~']
# [0, 'c"']
# [0, '_s']
# [0, ']R']
# [0, '&\x0b']
# [0, 'jp']
# [0, 'P}']
# [0, '*,']
# [0, '\rP']
# [0, 'fK']
# [0, ';0']
# [0, '-%']
# [0, 'lT']
# [0, '-Z']
# [0, 'x\t']
# [0, 'v-']
# [0, 'H~']
# [0, 'V ']
# [0, '=/']
# [0, 'PO']
# [0, 'KC']
# [0, '/n']
# [0, 'zL']
# [0, '{b']
# [1, '[a']
# [0, 'm ']
# [0, 'g/']
# [0, 'DQ']
# [0, '%0']
# [0, '>}']
# [0, 'Ps']
# [0, 'G#']
# [0, 'pL']
# [0, 'Xq']
# [0, 'S^']
# [0, 'Y2']
# [0, 'j:']
# [0, 'o\r']
# [0, '^Z']
# [0, 'by']
# [0, 'u9']
# [0, '5t']
# [0, 'f1']
# [0, 'w|']
# [0, '-#']
# [0, 'A?']
# [0, 'r?']
# [0, 'O,']
# [0, '06']
# [0, 'DC']
# [0, 'o}']
# [0, '_s']
# [0, '\rC']
# [0, '>.']
# [0, ' -']
# [0, 'A4']
# [0, 'd1']
# [0, 'kF']
# [0, '?8']
# [0, '^@']
# [0, '\x0cx']
# [0, '%+']
# [0, '3"']
# [0, '?e']
# [0, 'fE']
# [0, '!,']
# [0, 'c2']
# [0, '$@']
# [0, 'Ak']
# [0, ':]']
# [1, '1`']
# [0, ')j']
# [0, 'Mw']
# [0, '{N']
# [0, ' O']
# [0, 'dI']
# [0, 'GF']
# [0, 'a2']
# [0, '-7']
# [0, '?h']
# [0, '\x0cn']
# [0, 'l4']
# [0, 'mk']
# [0, '^7']
# [0, 'K4']
# [0, '^1']
# [0, "'b"]
# [0, '}6']
# [0, "l'"]
# [0, '$9']
# [0, 'j\x0c']
# [0, 't4']
# [0, 'p5']
# [0, 'Sx']
# [0, 'iT']
# [0, 'yY']
# [0, 'mS']
# [0, 'ht']
# [0, 'o5']
# [0, ' 6']
# [0, 'Gw']
# [0, '@C']
# [0, ':\t']
# [0, 'Zd']
# [0, 's/']
# [0, '}g']
# [0, '9E']
# [0, 'do']
# [1, '1`']
# [0, '}d']
# [0, 'PQ']
# [0, 'gk']
# [0, '3s']
# [0, 'Mb']
# [0, 'IS']
# [0, 'of']
# [0, '_b']
# [0, '.9']
# [0, ')i']
# [0, 'HB']
# [0, '?M']
# [0, 'sE']
# [0, '-X']
# [0, ',P']
# [0, 'g8']
# [0, '\ro']
# [0, 'HQ']
# [0, 'O]']
# [0, 'Rc']
# [0, '\\/']
# [0, '(c']
# [0, '\n:']
# [0, 'b"']
# [0, '8Q']
# [0, '\x0b^']
# [0, 'Op']
# [0, 'R#']
# [0, 'ZP']
# [0, '|0']
# [0, '-V']
# [0, ':)']
# [0, '.L']
# [0, '\x0b:']
# [0, 'Qi']
# [0, '97']
# [0, '(G']
# [0, '{!']
# [0, "'o"]
# [0, 'A\x0b']
# [0, "'f"]
# [0, ';\r']
# [0, 'i@']
# [0, 'L{']
# [0, '>C']
# [0, '\tS']
# [0, 'P_']
# [0, 'M*']
# [0, '|D']
# [0, 'r]']
# [0, 'aP']
# [0, 'wg']
# [0, 'A\x0b']
# [0, '2\n']
# [0, 'L*']
# [0, '9:']
# [0, '@|']
# [0, '@5']
# [0, 'i1']
# [0, 'GV']
# [0, '@>']
# [0, 'N{']
# [0, '}Z']
# [0, '_)']
# [0, '$Z']
# [0, 'Y\t']
# [0, '/<']
# [0, '$!']
# [0, 'l>']
# [0, 'i+']
# [0, 'IN']
# [0, '=O']
# [0, '3K']
# [0, 'ji']
# [0, 'jg']
# [0, 'Z[']
# [0, 'I\r']
# [1, '1x']
# [0, 'lo']
# [0, '0P']
# [0, 'QR']
# [0, 'Jg']
# [0, 'E,']
# [0, 'fA']
# [0, 'K1']
# [0, '}s']
# [0, '}J']
# [0, 'N3']
# [0, ',S']
# [0, ':N']
# [0, '^8']
# [0, 'V6']
# [0, 'Of']
# [0, ':$']
# [0, '7d']
# [0, 'eG']
# [0, 'j_']
# [0, 'Y\x0b']
# [0, ']\\']
# [0, '_U']
# [0, 'a&']
# [0, 'c+']
# [0, ']W']
# [0, 'E_']
# [0, 'aM']
# [0, '3*']
# [0, 's3']
# [0, 'O@']
# [0, 'qp']
# [0, '-/']
# [0, 'k-']
# [0, '7t']
# [0, 'z6']
# [0, 'Gu']
# [0, '~ ']
# [0, '%\r']
# [0, 'N+']
# [0, 'h,']
# [0, 'wT']
# [0, '_]']
# [0, '\nG']
# [0, 'T%']
# [0, '8S']
# [0, 'HR']
# [0, 'QS']
# [0, 'j+']
# [0, 'Lf']
# [0, '`2']
# [0, 'A<']
# [0, 'y_']
# [0, 'MO']
# [0, 'e\n']
# [0, 'ej']
# [0, 'sJ']
# [0, 'Ek']
# [0, '%I']
# [0, '*)']
# [0, '%}']
# [0, '&H']
# [0, 'E\x0b']
# [0, 'iL']
# [0, 'J4']
# [0, 'h>']
# [0, 'ct']
# [0, '/y']
# [0, '*M']
# [0, 'nZ']
# [0, '}.']
# [0, '\x0b@']
# [0, 'A8']
# [0, 'QF']
# [0, 'T|']
# [0, '}g']
# [0, '{\\']
# [0, '0p']
# [0, 'eg']
# [0, '+=']
# [0, 'X<']
# [0, ',D']
# [0, 'Xs']
# [0, '!2']
# [0, '9|']
# [0, 'D;']
# [0, 'z|']
# [0, '<v']
# [0, '[\t']
# [0, '/5']
# [0, '&6']
# [0, 'Od']
# [0, '3x']
# [0, 'a6']
# [0, '.^']
# [0, '}|']
# [0, ' 9']
# [0, 'J?']
# [0, '#6']
# [0, 'N^']
# [0, 'V#']
# [0, 'q!']
# [0, '-S']
# [0, 'Z+']
# [0, 'v,']
# [0, 'e4']
# [0, 'AJ']
# [0, 'j"']
# [0, 'ws']
# [0, 'v9']
# [0, '^I']
# [0, 'dT']
# [0, '+\n']
# [0, 'm%']
# [0, '}x']
# [0, 'V2']
# [0, 'Cf']
# [0, 'ki']
# [0, ' v']
# [0, '!O']
# [1, 'Ia']
# [0, 'E,']
# [0, 'f)']
# [0, ' g']
# [0, 'Ne']
# [0, 'BL']
# [0, '_[']
# [0, '&Z']
# [0, '5?']
# [0, 'zx']
# [0, 'yF']
# [0, '27']
# [0, 'Z*']
# [0, 'gk']
# [0, 'uY']
# [0, '\\F']
# [0, 'I}']
# [0, 'H&']
# [0, 'T.']
# [0, 'K8']
# [0, 'Kt']
# [0, 'f ']
# [0, "Y'"]
# [0, '+*']
# [0, ':u']
# [0, '!{']
# [0, 'kT']
# [0, '8]']
# [0, '(`']
# [0, '8]']
# [0, 'JH']
# [0, 'ch']
# [0, ')f']
# [0, ' o']
# [0, '|T']
# [0, '?[']
# [0, 'n&']
# [0, '=j']
# [0, 'IM']
# [0, 'rv']
# [1, '1f']
# [0, '@c']
# [0, '{v']
# [0, 'SC']
# [0, 't-']
# [0, 'mu']
# [0, '"3']
# [1, 'Ua']
# [0, '> ']
# [0, 'Qv']
# [0, 'q0']
# [0, 'T\x0b']
# [0, 'Cn']
# [0, 'z"']
# [0, '76']
# [0, '";']
# [0, ')H']
# [0, 'E<']
# [0, '(H']
# [0, 'sB']
# [0, 'U{']
# [0, '#h']
# [0, '\\N']
# [0, '/7']
# [0, '*:']
# [0, 'M}']
# [0, '7C']
# [0, 'Bq']
# [1, '17']
# [0, 'o<']
# [1, '1v']
# [0, 'F9']
# [0, '\t0']
# [0, 'Us']
# [0, ')M']
# [0, 'AN']
# [0, 'pU']
# [0, '"&']
# [0, 'qt']
# [0, 'Ff']
# [0, '\\t']
# [0, '!R']
# [0, 'KY']
# [0, "'n"]
# [0, 'A,']
# [0, 'c(']
# [0, '$N']
# [0, '>Z']
# [0, '"\x0c']
# [0, 'Z1']
# [0, 'rl']
# [0, '\x0c ']
# [0, 'E\\']
# [0, 'Nq']
# [0, 't1']
# [0, 'cf']
# [0, 'z*']
# [0, 'bQ']
# [0, '}r']
# [0, 'B[']
# [0, '>`']
# [0, 'V\n']
# [0, 'nE']
# [0, ']\t']
# [0, '#\x0c']
# [0, 'H+']
# [0, 'ws']
# [0, 'bB']
# [0, 'D2']
# [0, 'VJ']
# [0, 'v{']
# [0, '\x0c\x0b']
# [0, 'Wn']
# [0, 'Z/']
# [0, ' d']
# [0, '+B']
# [0, '!{']
# [0, 'oS']
# [0, '{\n']
# [0, "s'"]
# [0, '~[']
# [0, '<U']
# [0, '^1']
# [0, '\nV']
# [0, '0\\']
# [0, 'RU']
# [0, 'UV']
# [0, '[k']
# [0, 's\r']
# [0, '\rQ']
# [0, "'Q"]
# [0, 'h9']
# [0, 'x0']
# [0, 'pJ']
# [0, 'pZ']
# [0, 'UO']
# [0, 'a{']
# [0, '[H']
# [0, 'Ug']
# [0, "'*"]
# [0, 's/']
# [0, '=1']
# [0, 'D!']
# [0, '+=']
# [0, '>r']
# [0, 'YT']
# [0, 'g,']
# [0, 'F ']
# [0, 'tg']
# [0, 'yC']
# [0, '6\r']
# [0, 'Rk']
# [0, 'He']
# [0, 'Q_']
# [0, ']\x0c']
# [0, '"~']
# [0, '\\J']
# [0, 'XD']
# [0, '|\x0b']
# [0, 'jX']
# [0, '(\x0c']
# [0, '0e']
# [0, 'V8']
# [0, 'V}']
# [0, 'Md']
# [0, 'Z{']
# [0, '~i']
# [0, 'E+']
# [0, '/@']
# [0, 'fd']
# [0, '+o']
# [0, '8t']
# [0, 'V[']
# [0, '*;']
# [0, 'Rn']
# [0, 'G\x0c']
# [0, 'JW']
# [0, '&|']
# [0, 'A8']
# [0, '\x0b{']
# [0, 'Kd']
# [0, '`T']
# [0, '$*']
# [0, 'Qg']
# [0, ';[']
# [0, '~I']
# [0, '[=']
# [0, 'NK']
# [0, 'j;']
# [0, '7!']
# [0, 'Jy']
# [0, '}%']
# [0, 'M\\']
# [0, 'r*']
# [0, '\r=']
# [0, '[%']
# [0, 'X^']
# [0, '@\\']
# [0, 'MP']
# [0, "'t"]
# [0, 'i^']
# [0, '-&']
# [0, 'xo']
# [0, 'ML']
# [0, 'V\x0c']
# [0, 'e[']
# [0, '*.']
# [0, 'so']
# [0, ')=']
# [0, '\rs']
# [0, '(*']
# [0, ']<']
# [0, '|q']
# [0, '6B']
# [0, 'nb']
# [0, 'u&']
# [0, 'qD']
# [0, 'F\t']
# [0, '0P']
# [0, '&/']
# [0, 'V>']
# [0, 'i0']
# [0, 'h1']
# [0, '?\r']
# [0, ':5']
# [0, 'b\n']
# [0, ')`']
# [0, 'm\x0c']
# [0, "\x0c'"]
# [0, '%Z']
# [0, 'm-']
# [0, '~c']
# [0, 'h/']
# [0, 'i:']
# [0, '#I']
# [0, '4u']
# [0, '{A']
# [0, 'bS']
# [0, 'hb']
# [1, '{a']
# [0, 'V4']
# [0, 'Sl']
# [0, 'ue']
# [0, 'lK']
# [0, '\x0cm']
# [0, 'Je']
# [0, '+Z']
# [0, '{8']
# [0, "D'"]
# [0, 'Zf']
# [0, 'mr']
# [0, 'bH']
# [0, 'y\x0c']
# [0, 'WL']
# [0, '^k']
# [0, 'rY']
# [0, 'm`']
# [0, 'q\r']
# [0, 'pl']
# [0, '~S']
# [0, '+v']
# [1, '1=']
# [0, ',G']
# [0, 'PA']
# [0, 'k|']
# [0, 'M ']
# [0, 'dp']
# [0, 'fh']
# [0, 'C!']
# [0, '^s']
# [0, '.*']
# [0, 'WI']
# [0, 'e\x0b']
# [0, 'lD']
# [0, 'WN']
# [0, 'O`']
# [0, ';\x0b']
# [0, 'W\t']
# [0, 'o2']
# [0, '@D']
# [0, '~E']
# [0, '\n=']
# [0, '@>']
# [0, 'M|']
# [0, '+\\']
# [0, '${']
# [0, 'Ah']
# [0, '\n:']
# [0, 'Op']
# [0, '!\n']
# [0, 'sB']
# [0, 'D(']
# [0, '.f']
# [0, '\x0c*']
# [0, '&T']
# [0, 'ZG']
# [0, 'y5']
# [0, '/A']
# [0, 'sN']
# [0, 'b?']
# [0, ',)']
# [0, 'M,']
# [1, 'ra']
# [0, 'Hv']
# [0, ':`']
# [0, 'S$']
# [0, '\x0b/']
# [0, '06']
# [0, 'fH']
# [0, '`%']
# [0, '`o']
# [0, 'T<']
# [0, ',2']
# [0, 'G5']
# [0, 'PC']
# [0, '@c']
# [0, 'jk']
# [0, '6(']
# [0, '/6']
# [0, 'n!']
# [0, 'cY']
# [0, 'OC']
# [0, '"0']
# [0, 'M\x0c']
# [0, 'oZ']
# [0, '^r']
# [0, 'h0']
# [0, 'Zb']
# [0, 'H!']
# [1, '1h']
# [0, ' \t']
# [0, 'EC']
# [0, ' 8']
# [0, 'ti']
# [0, 'SZ']
# [0, '\x0c)']
# [0, '}<']
# [0, 'c\\']
# [0, '/4']
# [0, 'yE']
# [0, '8%']
# [0, '5 ']
# [0, 'eu']
# [0, 'iB']
# [0, '_<']
# [0, '^@']
# [0, '(b']
# [0, 'g.']
# [0, 'Z.']
# [0, 'k1']
# [0, ';-']
# [0, 'cz']
# [0, 'u)']
# [0, '?e']
# [0, 'F~']
# [0, 'OK']
# [0, 'Wt']
# [0, 'hq']
# [0, '\rl']
# [0, 'f0']
# [0, 'lO']
# [0, '\n\\']
# [0, '[h']
# [0, '"M']
# [0, ' ~']
# [0, 'O]']
# [0, 'Tk']
# [0, 'a$']
# [0, 'Ff']
# [0, 'W-']
# [0, '.0']
# [0, '\r{']
# [0, ' P']
# [0, '^v']
# [0, '{8']
# [0, '#b']
# [0, 'LI']
# [0, 'Q9']
# [0, '(6']
# [0, '.V']
# [0, '"!']
# [0, 'W#']
# [0, 'T,']
# [0, '6$']
# [0, '{P']
# [0, 'G7']
# [0, 'r#']
# [1, '%a']
# [0, '!\n']
# [0, '0n']
# [0, 'h)']
# [1, 'Ha']
# [0, 'Bh']
# [0, ' W']
# [0, '; ']
# [0, 'YZ']
# [0, 'MI']
# [0, 'u}']
# [0, '`M']
# [0, 'Y&']
# [0, 'SO']
# [0, '(8']
# [0, '>p']
# [0, 'bW']
# [0, 'l,']
# [0, 'Gl']
# [0, 'r~']
# [0, 'KC']
# [0, ' ?']
# [0, 'G9']
# [0, 'Po']
# [0, '9b']
# [0, 'Hk']
# [0, 'RB']
# [0, 'p)']
# [0, '[$']
# [0, 'NR']
# [0, '?\x0b']
# [0, '\\!']
# [0, 'X0']
# [0, 't`']
# [0, '.`']
# [0, ';:']
# [0, 'vN']
# [0, 'b*']
# [0, '^G']
# [0, '^E']
# [0, 'fx']
# [0, 'iU']
# [0, ',\x0c']
# [0, '$.']
# [0, "u'"]
# [0, '\x0cG']
# [0, 'r~']
# [0, 'kn']
# [0, 'a*']
# [0, 'Rp']
# [0, ')N']
# [0, '\\3']
# [0, 'R)']
# [0, 'lK']
# [0, 'xU']
# [0, 'gF']
# [0, '!.']
# [0, ' J']
# [0, '$!']
# [0, 'E5']
# [0, '2;']
# [0, ' x']
# [0, 'He']
# [0, '[G']
# [0, 'N\r']
# [0, '_;']
# [0, 'Zg']
# [0, '(<']
# [0, '":']
# [0, '.y']
# [0, 'NZ']
# [0, '"-']
# [0, '|E']
# [0, 'q}']
# [0, 'UN']
# [0, 'xF']
# [0, '$r']
# [0, '@Z']
# [0, 'f?']
# [0, ':F']
# [0, 'nG']
# [0, 'Q=']
# [0, '8*']
# [0, 'N2']
# [0, 'c&']
# [0, '>r']
# [0, '(0']
# [0, '\\v']
# [0, 'ae']
# [0, 'ds']
# [0, 'iW']
# [0, '#%']
# [0, '\nS']
# [0, '0\t']
# [0, ',h']
# [0, 'O~']
# [0, 'L|']
# [0, 'm/']
# [0, '8/']
# [0, '6\x0c']
# [0, '@?']
# [0, 'k(']
# [0, '+(']
# [0, 'x?']
# [0, 'XL']
# [0, '_U']
# [0, ">'"]
# [0, 'V+']
# [0, 'xr']
# [0, 'B\n']
# [0, 'G\x0b']
# [0, ',\r']
# [0, 'Io']
# [0, 'E;']
# [0, '*4']
# [0, 'T5']
# [0, 'JC']
# [0, 'Pf']
# [0, 'nT']
# [0, '_]']
# [0, 'im']
# [0, 'er']
# [0, 'yV']
# [0, '|s']
# [0, '>L']
# [0, ']i']
# [0, 'k^']
# [0, ' }']
# [0, '{I']
# [0, 'l!']
# [0, 'kG']
# [0, 'I/']
# [0, ')W']
# [0, '! ']
# [0, '3I']
# [0, 'PH']
# [0, '&K']
# [0, '$\\']
# [0, 'FV']
# [0, 'S=']
# [0, 'g9']
# [0, '&@']
# [0, 'di']
# [0, 'x@']
# [0, ':|']
# [0, 'FS']
# [0, '@8']
# [0, 'w<']
# [0, 'X/']
# [0, '-?']
# [0, '`z']
# [0, 'r\t']
# [0, 'oe']
# [0, '3p']
# [0, 'IB']
# [0, '>+']
# [0, 'Sg']
# [0, '[.']
# [0, '(_']
# [0, '\rr']
# [0, '"5']
# [0, 'G}']
# [0, "d'"]
# [0, 'J>']
# [0, '3c']
# [0, '\x0co']
# [0, 'D_']
# [0, '4O']
# [0, 'r>']
# [0, 'q{']
# [0, 'n)']
# [0, 'c2']
# [0, '+?']
# [0, '5m']
# [0, '#c']
# [0, 'H{']
# [0, 'no']
# [0, 'ik']
# [0, 'Y{']
# [0, '|z']
# [0, 'ut']
# [0, 'DE']
# [0, 'wk']
# [0, 'zi']
# [0, 'Xe']
# [0, '87']
# [0, '\x0bk']
# [0, '.6']
# [0, 'dp']
# [0, '<o']
# [0, 'Em']
# [0, 'pB']
# [0, 'sG']
# [0, 't5']
# [0, '"Q']
# [0, 'nD']
# [0, 'hO']
# [0, 'zn']
# [0, 'H7']
# [0, 'A"']
# [0, '$e']
# [0, '34']
# [0, '{7']
# [0, 'g\x0b']
# [0, 'Vn']
# [0, 'E|']
# [0, '@y']
# [0, 'g8']
# [0, '+2']
# [0, '=|']
# [0, 'W&']
# [0, '0w']
# [0, '4}']
# [0, 'n(']
# [0, '$P']
# [0, '4\x0b']
# [0, '\x0c+']
# [0, '\nU']
# [0, 't@']
# [0, '8$']
# [0, '5=']
# [0, 'X6']
# [0, 'tu']
# [0, 'iJ']
# [0, 'M2']
# [0, 'cg']
# [0, 'A\x0b']
# [0, 'l\r']
# [0, 'p ']
# [0, 'AI']
# [0, '&S']
# [0, '@~']
# [0, '^N']
# [0, 'I;']
# [0, 'kL']
# [0, 'G\t']
# [0, '6C']
# [0, "x'"]
# [0, 'w0']
# [0, 'r&']
# [0, "'\r"]
# [0, 'LT']
# [0, '(i']
# [0, 'WF']
# [0, 'a]']
# [0, '\r%']
# [0, 'z6']
# [0, 'vI']
# [0, 'ed']
# [1, '1P']
# [0, 'qJ']
# [0, 'w%']
# [0, '9f']
# [0, 'p"']
# [0, ']h']
# [0, '#g']
# [0, ',t']
# [0, '&)']
# [0, '_7']
# [0, 'GW']
# [0, 'Ys']
# [0, 'BD']
# [0, 'ZE']
# [0, 'Jv']
# [0, '\\N']
# [0, '6e']
# [0, 'hl']
# [0, 'E1']
# [0, '&c']
# [0, '?<']
# [0, '+t']
# [0, '(j']
# [0, '2`']
# [0, '|:']
# [0, 'C\r']
# [0, 'p4']
# [0, 'L#']
# [0, 'k@']
# [0, 'Y,']
# [0, 'Pg']
# [0, ' B']
# [0, ':!']
# [0, '{9']
# [0, 'Rl']
# [0, '4E']
# [0, ';k']
# [0, 'z6']
# [0, '-C']
# [0, '(2']
# [0, 'iL']
# [0, '\nz']
# [0, 'rK']
# [0, 'o:']
# [0, 'QM']
# [0, '{\x0c']
# [0, 'sA']
# [0, '=V']
# [0, 'Y6']
# [0, '^C']
# [0, '\nQ']
# [0, 'TJ']
# [0, 'LN']
# [0, '?J']
# [0, 'T^']
# [0, '<B']
# [0, 'x8']
# [0, 'Q.']
# [0, ' %']
# [0, ')|']
# [0, '4)']
# [0, 'iX']
# [0, '\nN']
# [0, 'w"']
# [0, 'jL']
# [0, 'fR']
# [0, '6V']
# [0, 'Mu']
# [0, '^\n']
# [0, 'Q:']
# [0, 'q(']
# [0, '/n']
# [0, '*(']
# [0, '9X']
# [0, ")'"]
# [0, '9\r']
# [0, 'MS']
# [0, 'rA']
# [0, 'p]']
# [0, 'O$']
# [0, 'J\\']
# [0, 'EL']
# [0, 'b=']
# [0, '.\t']
# [0, '>\r']
# [0, 'iB']
# [0, 'Kv']
# [0, 'b1']
# [0, 'uf']
# [0, ';"']
# [0, '>]']
# [0, 'Y\x0b']
# [0, '*G']
# [0, 'ns']
# [0, 'x$']
# [0, 'js']
# [0, '\nD']
# [0, '4L']
# [0, '#M']
# [0, ',j']
# [0, '+]']
# [0, 'F~']
# [0, 'dA']
# [0, "'j"]
# [0, '2&']
# [0, 'B\n']
# [0, '&K']
# [0, '({']
# [0, '+O']
# [0, 'Yl']
# [0, 'c-']
# [0, 'M9']
# [0, '"%']
# [0, '\x0cd']
# [0, 'Ne']
# [0, 'PY']
# [0, 'a=']
# [0, 'hu']
# [0, 'km']
# [0, ';K']
# [0, '0B']
# [0, 'N ']
# [0, 'u+']
# [0, 'O$']
# [0, 'A2']
# [0, 'n0']
# [0, '{:']
# [1, '1k']
# [0, 'p:']
# [0, 'SQ']
# [0, '/A']
# [0, 'G;']
# [0, '>\x0b']
# [0, '6U']
# [0, '/[']
# [0, 'PO']
# [0, 'R/']
# [0, 's%']
# [0, 'A(']
# [0, '39']
# [0, '9j']
# [0, 'He']
# [0, 'X[']
# [0, 'Z\r']
# [0, 'cl']
# [0, 'g/']
# [0, ',4']
# [0, 'oh']
# [0, '2B']
# [0, '*\\']
# [0, 'IB']
# [0, ';x']
# [0, 'M`']
# [0, 'qf']
# [0, 'F"']
# [0, 'M.']
# [0, 'YW']
# [0, 'r"']
# [0, '+{']
# [0, '@T']
# [0, 'Qe']
# [0, 'x]']
# [0, ' ]']
# [0, 'g5']
# [0, '$#']
# [0, 'H\n']
# [0, 'a-']
# [0, 'm:']
# [0, 'Lc']
# [0, 'rJ']
# [0, 'P#']
# [0, 'C\r']
# [0, 'Sm']
# [0, 'pH']
# [0, 'kz']
# [0, 'fJ']
# [0, '4:']
# [0, 'W@']
# [0, 'AZ']
# [0, ')V']
# [0, 'j ']
# [0, 'KL']
# [0, 'xX']
# [0, '*+']
# [0, '\\o']
# [0, 'Z@']
# [0, 'zs']
# [0, '4>']
# [0, '9G']
# [0, 'SE']
# [0, 'Iv']
# [0, 'kE']
# [0, '#j']
# [0, 'r}']
# [0, 'x]']
# [0, '#s']
# [0, 'Z5']
# [0, 'qs']
# [0, 'T\\']
# [0, 'sG']
# [0, '_(']
# [0, 'rP']
# [0, 'vT']
# [0, 'Qc']
# [0, '#*']
# [0, '0\n']
# [0, '2l']
# [0, '\x0c8']
# [0, '\t:']
# [0, '-A']
# [0, '&X']
# [0, '~3']
# [0, 'E{']
# [0, '"*']
# [0, '=-']
# [0, '[Q']
# [0, 't{']
# [0, '|\\']
# [0, '[G']
# [0, 'zt']
# [0, '>O']
# [0, 'ZT']
# [0, 'I,']
# [0, 'eh']
# [0, 'T/']
# [0, 'Q.']
# [0, 'v(']
# [0, 'O1']
# [0, '\x0c*']
# [1, '1x']
# [0, 'CM']
# [1, '@a']
# [0, 'E*']
# [0, '3p']
# [0, "'O"]
# [0, 'Tl']
# [0, '%n']
# [0, 'hk']
# [0, 'v|']
# [0, '"?']
# [0, '.3']
# [0, 'Y|']
# [0, 'kh']
# [0, '/Z']
# [0, '4)']
# [0, 'R@']
# [0, '_=']
# [0, 'p%']
# [0, ':}']
# [0, '),']
# [0, 'G;']
# [0, 'P\n']
# [0, 'Hx']
# [0, '+5']
# [0, 'TB']
# [0, '0X']
# [0, '3)']
# [0, 'B-']
# [0, '-P']
# [0, '+N']
# [0, '&n']
# [0, '-9']
# [0, 'W$']
# [0, 'Jd']
# [0, '5V']
# [0, "'}"]
# [0, 'V0']
# [0, '/z']
# [0, '`F']
# [0, '~^']
# [0, 'F+']
# [0, '5M']
# [0, '}\\']
# [0, '42']
# [0, 'c,']
# [0, '\x0b\n']
# [0, '[n']
# [0, '{"']
# [0, '$p']
# [0, 'P.']
# [0, 'J9']
# [0, 'J>']
# [0, '%X']
# [0, '\\.']
# [0, '/I']
# [0, '4f']
# [0, ':]']
# [0, '/3']
# [0, 'wh']
# [0, 'kB']
# [0, 'B%']
# [0, '\nb']
# [0, ':7']
# [0, 'fy']
# [0, 'Gd']
# [0, '(@']
# [0, '_G']
# [1, '1J']
# [0, 'r_']
# [0, 'i(']
# [0, '\r8']
# [0, 'YV']
# [0, 'ZG']
# [0, '_U']
# [0, 'E]']
# [0, 'Xz']
# [0, 'rF']
# [0, 'k/']
# [0, '5i']
# [0, '3/']
# [0, 'ct']
# [0, 'i&']
# [0, 'GO']
# [0, '_"']
# [0, ':_']
# [0, 'Zs']
# [0, ')\n']
# [0, 'am']
# [0, '#I']
# [0, 'SD']
# [0, 'N$']
# [0, '.x']
# [0, '7w']
# [0, 'q+']
# [0, 't$']
# [0, 'V&']
# [0, 'H7']
# [0, '[p']
# [0, 'H+']
# [0, '~c']
# [0, '!Z']
# [0, 'H\r']
# [0, 'K1']
# [0, '9(']
# [0, '`)']
# [0, '_.']
# [0, '.2']
# [0, 'oI']
# [0, '\r4']
# [0, 'W)']
# [0, 'PZ']
# [1, '>a']
# [0, 'H9']
# [0, 'od']
# [0, '*%']
# [0, '`M']
# [0, '\tB']
# [0, 'R(']
# [0, 'fd']
# [0, '\\Y']
# [0, '[J']
# [0, 'N=']
# [0, '}/']
# [0, 'EP']
# [0, '\x0cj']
# [0, 'wc']
# [0, 'S=']
# [0, 'wQ']
# [0, 'NE']
# [0, '_Z']
# [0, '78']
# [0, 'W"']
# [0, '5e']
# [0, 'dc']
# [0, 'hI']
# [0, '\nA']
# [0, 'Tj']
# [0, 'Eb']
# [0, 'Mg']
# [0, '_/']
# [0, '\r+']
# [0, '\ti']
# [0, 'c^']
# [0, 'p1']
# [0, 'Ei']
# [0, 'cL']
# [0, '6k']
# [0, 'Sd']
# [0, 'BQ']
# [0, 'T&']
# [0, '\nZ']
# [0, '>v']
# [0, 'GQ']
# [0, 'QV']
# [0, 'D[']
# [0, 'WK']
# [0, '^1']
# [0, '\\A']
# [0, 'O!']
# [0, ' Y']
# [0, 'e[']
# [0, '6c']
# [0, 'mJ']
# [0, 'c]']
# [0, '0l']
# [0, '?M']
# [0, ',h']
# [0, 'dG']
# [0, 'j4']
# [0, 'me']
# [0, 'G{']
# [0, 'Fe']
# [0, 'fD']
# [0, 'c`']
# [0, 'pr']
# [0, '_2']
# [0, 'q`']
# [0, '9L']
# [0, '{)']
# [1, '1O']
# [0, '/V']
# [0, '3r']
# [0, '_p']
# [0, 'Pu']
# [0, 'P[']
# [0, 'r4']
# [0, '/T']
# [0, '\rG']
# [0, 'Wb']
# [0, 'Pq']
# [0, 'c;']
# [0, '\t]']
# [0, 'n9']
# [0, '$Q']
# [0, '/D']
# [0, '+f']
# [0, 'x#']
# [0, '8G']
# [0, 'ZD']
# [0, '`9']
# [0, 'w;']
# [0, 'n%']
# [0, "\t'"]
# [0, 'zD']
# [0, '5|']
# [0, '0P']
# [0, 'a{']
# [0, 'WQ']
# [0, 'P\t']
# [0, '31']
# [0, 'Ym']
# [0, 'wZ']
# [0, '-l']
# [0, '\x0c7']
# [0, 'ES']
# [0, 'W@']
# [0, 'm|']
# [0, '0~']
# [0, 'Mx']
# [0, 'i<']
# [0, 'TC']
# [0, '>D']
# [0, 'i>']
# [0, 'a3']
# [0, 'Yp']
# [0, 'kH']
# [0, '$I']
# [0, '-9']
# [0, ']\\']
# [0, '/>']
# [0, ',\n']
# [0, '90']
# [0, 'lr']
# [0, ':t']
# [0, '2%']
# [0, '-4']
# [0, 'LM']
# [0, 'fF']
# [0, '._']
# [0, 'sl']
# [0, '{.']
# [0, ';D']
# [0, 'S@']
# [0, 'pS']
# [0, '&O']
# [0, '?A']
# [0, 'qB']
# [0, '.A']
# [0, '%B']
# [0, 'Q8']
# [0, 'Tl']
# [0, '}U']
# [0, 'jQ']
# [0, 'M.']
# [0, '@D']
# [0, '\rh']
# [0, 'Mj']
# [0, '#-']
# [0, '}@']
# [0, '\x0cx']
# [0, 'fg']
# [0, ':-']
# [0, ':%']
# [0, 'ZH']
# [0, '5u']
# [0, 'Pu']
# [0, '@B']
# [0, 'TN']
# [0, '0D']
# [0, 'pe']
# [0, 'g/']
# [0, 'B}']
# [0, './']
# [0, 'kW']
# [0, 'B8']
# [0, 'PE']
# [0, '\\H']
# [0, 'p3']
# [0, 'nc']
# [0, '?>']
# [0, '=o']
# [0, 'Z2']
# [0, '=o']
# [0, ':[']
# [0, 'ZJ']
# [0, '&s']
# [0, 'LW']
# [0, 'rW']
# [0, 'k\t']
# [0, 'De']
# [0, '&l']
# [0, '4m']
# [0, 'W$']
# [0, 'aQ']
# [0, 'kA']
# [0, '^1']
# [0, 'B3']
# [0, 'bt']
# [0, 'O\x0b']
# [0, 'i9']
# [0, '.[']
# [0, 'vl']
# [0, '.D']
# [0, 'VQ']
# [0, 'dy']
# [0, '(.']
# [0, 'b+']
# [0, 'H}']
# [0, '9J']
# [0, 'Dr']
# [0, '$w']
# [0, '\r-']
# [0, 'SA']
# [0, "'Y"]
# [0, 'ot']
# [0, 'Gj']
# [0, '^)']
# [0, "s'"]
# [0, '5$']
# [0, 'Z|']
# [0, 'T*']
# [0, '^V']
# [0, 'BQ']
# [0, 'm6']
# [0, '~o']
# [0, '*n']
# [0, 'ld']
# [0, 'n\t']
# [0, 'G;']
# [0, '&`']
# [0, 'o!']
# [0, '\x0cH']
# [0, '[b']
# [0, 'k!']
# [0, 'C&']
# [0, 'wW']
# [0, ' ?']
# [0, 'l)']
# [0, '.q']
# [0, 'o\x0c']
# [0, '6n']
# [0, '[x']
# [0, 'i0']
# [1, '1|']
# [0, 'u\x0b']
# [0, 'pQ']
# [0, '>n']
# [0, 'Op']
# [0, '{.']
# [0, ' Q']
# [0, 'D\r']
# [0, '0Q']
# [0, '!,']
# [0, '"u']
# [0, 'J_']
# [0, 'db']
# [0, 'T*']
# [0, '[f']
# [0, 'vS']
# [0, 'Q=']
# [0, '5\t']
# [0, ' z']
# [0, 'yw']
# [0, 'Hd']
# [0, 'r\\']
# [0, '\rf']
# [0, '@Y']
# [0, ':4']
# [0, 'dD']
# [0, '"\t']
# [0, ':x']
# [0, 'V.']
# [0, 'T ']
# [0, 'o@']
# [0, '0W']
# [0, 'lk']
# [0, 'Pj']
# [0, 'lJ']
# [0, 'Lg']
# [0, '\r\x0b']
# [0, 'g\\']
# [0, '_<']
# [1, '1.']
# [0, 'J|']
# [0, '@3']
# [0, '3\t']
# [0, 'yH']
# [1, 'Ba']
# [0, '#u']
# [0, 'p-']
# [0, '=\r']
# [0, ':^']
# [0, 'fl']
# [0, '"?']
# [0, '#M']
# [0, 'i\r']
# [0, '}\\']
# [0, 'v\x0c']
# [0, 'Lo']
# [0, 'hI']
# [0, '~r']
# [0, '9\x0b']
# [0, 'dN']
# [0, '.\x0b']
# [0, 'b7']
# [0, '\ny']
# [0, '5O']
# [1, '1G']
# [0, 'Hz']
# [0, '0\x0b']
# [0, '5Y']
# [0, 'VB']
# [0, 'VU']
# [0, '[g']
# [0, 'SF']
# [0, '9\x0b']
# [0, '~8']
# [0, '+g']
# [0, 'p)']
# [0, '=Z']
# [0, '\x0b\r']
# [0, '&h']
# [0, '|z']
# [0, 'X^']
# [0, 'O ']
# [0, 'yO']
# [0, '2g']
# [0, '\x0b(']
# [0, 'Pl']
# [0, '_|']
# [0, 'W\r']
# [0, 'x{']
# [0, 'Vt']
# [0, '=[']
# [0, 'go']
# [0, '*u']
# [0, 'JG']
# [0, '<M']
# [0, 'T\x0c']
# [0, '/h']
# [0, 'oy']
# [0, 'My']
# [0, 'xp']
# [0, '%x']
# [0, '4n']
# [0, 'Xx']
# [0, 'Q\\']
# [0, 'B^']
# [0, '<k']
# [0, '[C']
# [0, 'D\r']
# [0, '#4']
# [0, '`<']
# [0, 'Ri']
# [0, '-9']
# [0, " '"]
# [0, '+\x0b']
# [0, 'j9']
# [0, 'OG']
# [0, 'u^']
# [0, 'e2']
# [0, '} ']
# [0, 'Tq']
# [0, 'DI']
# [0, '.B']
# [0, 'x\\']
# [0, 'Q?']
# [0, 'BR']
# [0, '}c']
# [0, 'Xk']
# [0, '2c']
# [0, ' w']
# [0, 'TI']
# [0, 'a$']
# [0, '>`']
# [0, 'Q`']
# [0, 'M\t']
# [0, '.D']
# [0, 'pt']
# [0, '4[']
# [0, 'XS']
# [0, '\x0cp']
# [0, '3[']
# [0, 'vi']
# [0, ':,']
# [0, 'e|']
# [0, 'vI']
# [0, 'up']
# [0, 'h!']
# [0, '\tf']
# [0, '-L']
# [0, '.k']
# [0, 'XQ']
# [0, 'Xn']
# [0, '}K']
# [0, '#[']
# [0, 'Z{']
# [0, 'lr']
# [0, 'h8']
# [0, 'w=']
# [0, 'Uc']
# [0, 'sC']
# [0, '\x0b!']
# [0, '9/']
# [0, 'k\x0b']
# [0, 'i%']
# [0, 'rS']
# [0, 'xQ']
# [0, 'yN']
# [0, 'uR']
# [0, 'ON']
# [0, 'Y3']
# [0, '_#']
# [0, 'T,']
# [0, ')/']
# [0, 'EQ']
# [0, '-j']
# [0, '\n\r']
# [0, 'TE']
# [0, 'jq']
# [0, ')z']
# [0, 'IY']
# [0, '*\x0b']
# [0, '+A']
# [0, '_~']
# [0, 'a&']
# [0, 'g]']
# [0, 'B"']
# [0, '7q']
# [0, 'L,']
# [0, '{K']
# [1, '17']
# [0, '6k']
# [0, 'IK']
# [0, 's5']
# [0, '^V']
# [0, '_R']
# [0, 'L#']
# [0, '&m']
# [0, '(O']
# [0, 'Z6']
# [1, '1F']
# [0, '%$']
# [0, '[y']
# [0, '*p']
# [0, 'O\r']
# [0, 'NV']
# [0, 'Fd']
# [0, 'B\\']
# [0, '5%']
# [0, '.S']
# [0, 'dE']
# [0, '4v']
# [0, 'Lw']
# [0, '[G']
# [0, 'K>']
# [0, '7d']
# [0, '|d']
# [0, '\tn']
# [0, ']\x0c']
# [0, 'jI']
# [0, '3k']
# [0, '+c']
# [0, 'aE']
# [0, 'J\t']
# [0, 'o\t']
# [0, '[8']
# [0, '<j']
# [0, '+(']
# [0, 'H<']
# [0, 'dC']
# [0, 'Xs']
# [0, 'k%']
# [0, '}c']
# [0, 'o(']
# [0, 'M4']
# [0, 'QD']
# [0, '4v']
# [0, ']%']
# [0, 'l)']
# [0, 'V.']
# [0, 'W6']
# [0, '*H']
# [0, '\x0bY']
# [0, 'Mv']
# [0, 'BJ']
# [0, 'rI']
# [0, '&s']
# [0, 'yr']
# [0, ')@']
# [0, '(4']
# [0, 'hf']
# [0, '&i']
# [0, 'bc']
# [0, '6%']
# [0, 'h%']
# [0, 'UE']
# [0, 'cO']
# [0, '<D']
# [0, 'T\x0b']
# [0, 'sw']
# [0, 'e|']
# [0, '=|']
# [0, '`R']
# [0, '4Z']
# [0, '?W']
# [0, '<b']
# [0, 'A9']
# [0, '@-']
# [0, '3|']
# [0, '8{']
# [0, 'j_']
# [0, '<-']
# [0, '!A']
# [0, 'p3']
# [0, '!]']
# [0, 'N(']
# [0, 'G3']
# [0, '*L']
# [0, '=e']
# [0, 'Y4']
# [0, 'U5']
# [0, 'U*']
# [0, '#H']
# [0, 'Kn']
# [0, 'A"']
# [0, '0y']
# [0, 'N[']
# [0, '\n\\']
# [0, 'PG']
# [0, '*2']
# [0, 'yO']
# [0, 'fv']
# [0, 'Sz']
# [0, '`/']
# [0, '[k']
# [0, '_|']
# [0, 'm?']
# [0, 'eL']
# [0, ' U']
# [0, 'z;']
# [0, '@9']
# [0, 'zL']
# [0, 's>']
# [0, '\r9']
# [0, 'T;']
# [0, 'IC']
# [0, 'Il']
# [0, '-7']
# [0, '$#']
# [0, '[Z']
# [0, '/y']
# [0, 'gw']
# [0, '6}']
# [0, '\\5']
# [0, '[3']
# [0, 'zF']
# [0, '+w']
# [0, ']R']
# [0, '3X']
# [0, 'NP']
# [0, '5`']
# [0, '@n']
# [0, '#4']
# [0, '{7']
# [0, 'cF']
# [0, '(U']
# [0, '_*']
# [0, 'x-']
# [0, '\x0bT']
# [0, '91']
# [0, '|@']
# [0, '#s']
# [0, '4S']
# [0, 'xg']
# [0, 'mD']
# [0, '%Z']
# [0, 'Jz']
# [0, 'VT']
# [0, 'u9']
# [0, "R'"]
# [0, 'Cn']
# [0, '.e']
# [0, 'T=']
# [0, '-\r']
# [0, 'KO']
# [0, 'H\x0b']
# [0, 'F7']
# [0, '6\\']
# [0, '\rG']
# [0, '9S']
# [0, '{`']
# [0, '$t']
# [0, 'Gq']
# [0, '\r*']
# [0, 'O5']
# [0, '#?']
# [0, 'Bc']
# [0, 'p\x0c']
# [0, '\t\r']
# [0, '-]']
# [0, '?-']
# [0, 'Kf']
# [0, "}'"]
# [0, 'r/']
# [0, '<$']
# [0, '0C']
# [0, '0)']
# [0, '\x0cl']
# [0, 'N\n']
# [0, '6f']
# [0, 'v6']
# [0, '>Z']
# [0, '9g']
# [0, '2\\']
# [0, 'l|']
# [0, 'E1']
# [0, '#&']
# [0, 'ER']
# [0, '\x0cn']
# [0, '7Y']
# [0, ')O']
# [0, '&]']
# [0, 'KE']
# [0, 'p}']
# [0, 'b[']
# [0, 'lf']
# [0, ')~']
# [0, '!y']
# [0, '<|']
# [0, '0G']
# [0, '!P']
# [0, 'Du']
# [0, '"4']
# [0, 'CM']
# [0, '@k']
# [0, '"^']
# [0, ";'"]
# [0, 'Bl']
# [0, 'P8']
# [0, '>N']
# [0, '4/']
# [0, '$#']
# [0, 'I(']
# [0, 'yK']
# [0, '{h']
# [0, 'u;']
# [0, ">'"]
# [0, 'E\x0c']
# [0, '`x']
# [0, '%<']
# [0, '7<']
# [0, 'E#']
# [0, 'CS']
# [0, 'K{']
# [0, ']5']
# [0, ':g']
# [0, '-Q']
# [0, '37']
# [0, '/\x0b']
# [0, '[0']
# [0, 'X8']
# [0, '5z']
# [0, 'QC']
# [0, 'x4']
# [0, 'sB']
# [0, '`m']
# [0, 'vR']
# [1, 'za']
# [0, 'W*']
# [0, 'b`']
# [0, '>A']
# [0, '"Z']
# [0, "'F"]
# [1, '\ta']
# [0, 'uL']
# [0, '|X']
# [0, '[#']
# [0, 'bK']
# [1, '@a']
# [0, '/A']
# [0, '~*']
# [0, '%]']
# [0, '7X']
# [0, 'Y<']
# [0, '8\t']
# [0, 'l$']
# [0, 'Wh']
# [0, 'r_']
# [0, '\n@']
# [0, "}'"]
# [0, '5C']
# [0, 'o/']
# [0, 'Q\x0c']
# [0, ")'"]
# [0, ':r']
# [0, 'q{']
# [0, '/O']
# [0, 'oc']
# [0, '0\\']
# [0, '+=']
# [0, '(I']
# [0, 'P\n']
# [0, 'u^']
# [0, '5\n']
# [0, '$6']
# [0, '[g']
# [0, ':r']
# [0, '* ']
# [0, 'N-']
# [0, '86']
# [0, 'Q(']
# [0, '>9']
# [0, "'{"]
# [0, 'PR']
# [0, 'FU']
# [0, ':V']
# [0, 't\x0c']
# [0, 't)']
# [0, 'W=']
# [0, ')!']
# [0, '9b']
# [0, '\t.']
# [0, 'V+']
# [0, '[(']
# [0, 'Ce']
# [0, 'Zt']
# [0, 'A{']
# [1, 'Na']
# [0, 'W]']
# [0, '/M']
# [0, ', ']
# [0, '2*']
# [0, '!O']
# [0, ';\\']
# [0, '\t ']
# [0, 't<']
# [0, 'L9']
# [0, '5Q']
# [0, '4S']
# [0, '=L']
# [0, '7s']
# [0, 'gF']
# [0, 'F;']
# [0, '\x0c\x0b']
# [0, '?i']
# [0, '`+']
# [0, 'ei']
# [0, 'GK']
# [0, 'yJ']
# [0, '*x']
# [0, 'SP']
# [0, '?j']
# [0, 'm"']
# [0, 'Th']
# [0, ')L']
# [0, 'NS']
# [0, '\ng']
# [0, 'wc']
# [0, 's>']
# [0, 'N>']
# [0, 'N#']
# [0, 'ib']
# [0, ' ]']
# [0, 'z\\']
# [0, ',y']
# [0, ':l']
# [0, 'c#']
# [0, 'nA']
# [1, ',a']
# [0, '\tB']
# [0, '>H']
# [0, '?G']
# [0, 'nh']
# [0, '|F']
# [0, '#N']
# [0, '(e']
# [1, '1_']
# [0, ';b']
# [0, 'u)']
# [0, 'n*']
# [0, '. ']
# [0, 'm#']
# [0, 'U}']
# [0, 'QB']
# [0, "'Y"]
# [0, '?k']
# [0, 'mV']
# [0, 'RM']
# [0, 'i6']
# [0, 'jM']
# [0, 'Y@']
# [0, 'Os']
# [0, "'3"]
# [0, '+)']
# [0, 'mt']
# [0, 'O.']
# [0, '/\r']
# [0, 'f ']
# [0, 'P7']
# [0, '~.']
# [0, '-V']
# [1, 'La']
# [0, 'o.']
# [0, '9\t']
# [0, 'l&']
# [0, 'JH']
# [0, '{k']
# [0, 'S?']
# [0, '<e']
# [0, '&*']
# [0, 'KS']
# [0, '_\r']
# [0, '(!']
# [0, '4p']
# [0, '7\r']
# [1, '1[']
# [0, 'M\r']
# [0, '8%']
# [0, 'R ']
# [0, 'iV']
# [0, 'J:']
# [0, 'x\t']
# [0, 'N4']
# [0, '=f']
# [0, 'Vn']
# [0, 'tl']
# [0, '/o']
# [0, 'Q@']
# [0, 'B!']
# [0, 'cT']
# [0, '=w']
# [0, 'N6']
# [0, 'Rf']
# [0, '|A']
# [0, '-;']
# [0, '2i']
# [0, '8f']
# [0, 'ab']
# [0, 'IJ']
# [0, 'z:']
# [0, 'c\t']
# [0, 'qg']
# [0, '|T']
# [0, 'nM']
# [0, '\tP']
# [0, 'z}']
# [1, ',a']
# [0, ']_']
# [0, 'V!']
# [0, ':\\']
# [0, ' Q']
# [0, '`8']
# [0, 'H`']
# [0, '7=']
# [0, 'JW']
# [0, '}n']
# [0, 'B;']
# [0, '~p']
# [0, '5@']
# [0, '<!']
# [0, '&_']
# [0, '[d']
# [0, '"k']
# [0, 'Pm']
# [0, 'wK']
# [0, ' V']
# [0, 'r#']
# [0, '2E']
# [0, ':}']
# [0, ',&']
# [0, 'SW']
# [0, '*=']
# [0, '\t\r']
# [0, '("']
# [0, '`q']
# [0, 'fK']
# [0, 'oI']
# [0, '(w']
# [0, 'qB']
# [0, ')\x0b']
# [0, '@]']
# [0, 'wQ']
# [0, '32']
# [0, 'Qn']
# [0, 'w@']
# [0, ' M']
# [0, 'cI']
# [0, '7y']
# [0, 'CM']
# [0, '!)']
# [0, 'Vl']
# [0, ']x']
# [0, 'iG']
# [0, '."']
# [0, 'jN']
# [0, 'E7']
# [0, '+P']
# [0, 'gC']
# [0, 'ZG']
# [0, 'HB']
# [0, 'jD']
# [0, 'eI']
# [0, '=3']
# [0, 'F#']
# [0, '/|']
# [0, '>`']
# [0, 'ae']
# [0, 'F&']
# [0, '^M']
# [1, 'Ea']
# [0, 'Y7']
# [0, 'LZ']
# [0, '\r\\']
# [0, '>X']
# [0, ':4']
# [0, 'Ek']
# [0, "'I"]
# [0, '\x0bE']
# [0, '#?']
# [0, '(!']
# [0, 'ls']
# [0, 'Xl']
# [0, 'i^']
# [0, '[,']
# [0, '-h']
# [1, 'da']
# [0, '%K']
# [0, 'r-']
# [0, 'VQ']
# [0, '%_']
# [0, '9v']
# [0, '\x0bI']
# [0, '_M']
# [0, '}O']
# [0, '6%']
# [0, 'J-']
# [0, 'K!']
# [0, ')K']
# [0, 'JU']
# [0, ',H']
# [0, 'aw']
# [0, '&@']
# [0, '#I']
# [0, 'XL']
# [0, 'M|']
# [0, 'Bh']
# [0, '5Y']
# [0, 'JP']
# [0, '{\x0c']
# [0, '0o']
# [0, 'G:']
# [1, '1Q']
# [0, 'L~']
# [0, '<4']
# [0, '?3']
# [0, 'NZ']
# [0, 'm;']
# [0, 'aJ']
# [0, 'mi']
# [0, '\x0c;']
# [0, '{x']
# [0, '\x0bL']
# [0, 'Hx']
# [0, '5q']
# [0, '"w']
# [0, 'GN']
# [0, 'V=']
# [0, 'IH']
# [0, '\t4']
# [0, 'YM']
# [0, '6<']
# [0, 'VF']
# [0, 'S|']
# [0, 'xD']
# [0, 'g4']
# [0, 'hY']
# [0, ']O']
# [0, 'Of']
# [0, 'O*']
# [0, '#m']
# [0, 'ic']
# [0, 'a2']
# [0, 'xq']
# [0, 'SI']
# [0, 'KY']
# [0, 'Mq']
# [0, '}q']
# [0, 'D6']
# [0, '6j']
# [0, ':M']
# [0, ' (']
# [0, 'rn']
# [0, 'S+']
# [0, '@0']
# [0, '.J']
# [0, 'C-']
# [0, 'gQ']
# [0, '-r']
# [0, '$L']
# [0, '2n']
# [0, ']`']
# [0, ':"']
# [0, '9r']
# [0, 'D\x0b']
# [0, 'K/']
# [0, '7*']
# [0, 'Hv']
# [0, 't`']
# [0, 'O&']
# [0, 'QE']
# [0, 'o*']
# [0, 'NJ']
# [0, '@4']
# [0, 'Ie']
# [0, ')M']
# [0, '@"']
# [0, '"S']
# [0, 'ob']
# [0, '=l']
# [0, '+m']
# [0, ':<']
# [0, '\x0bI']
# [0, '[]']
# [0, '6k']
# [0, 'i[']
# [0, '7T']
# [0, 'a2']
# [0, 'qU']
# [0, '2!']
# [0, 'Dx']
# [0, '04']
# [0, '|!']
# [0, '~X']
# [0, '7B']
# [0, '-?']
# [0, '(D']
# [0, 'vu']
# [0, ':j']
# [0, 'u>']
# [0, '\x0c&']
# [0, '-3']
# [0, ':o']
# [0, '^\n']
# [0, '-0']
# [0, ':[']
# [0, 'Cz']
# [0, '$/']
# [0, '#V']
# [0, 'sf']
# [0, '<c']
# [0, 'Qk']
# [0, 'T/']
# [0, 'p ']
# [0, ',~']
# [0, ':\\']
# [0, 'ry']
# [0, 'Y[']
# [0, '&P']
# [0, '#\r']
# [0, 'O;']
# [0, 'R;']
# [0, 'X.']
# [0, '}0']
# [0, 'w!']
# [0, 'd|']
# [0, 'T\n']
# [0, 'p7']
# [0, ':\t']
# [0, 'pg']
# [0, ')#']
# [0, '^\\']
# [0, '\\ ']
# [0, 'xE']
# [0, 'E1']
# [0, 'Xv']
# [1, '1l']
# [0, '(m']
# [0, 'H+']
# [0, 'a=']
# [0, 'Q4']
# [0, '>K']
# [0, 'Z}']
# [0, '\t&']
# [0, 'O6']
# [0, '"!']
# [0, '\x0bf']
# [0, 'V`']
# [0, 'bW']
# [0, 'Ai']
# [0, '\x0b+']
# [0, 'c`']
# [0, '\tI']
# [0, 'py']
# [0, ';1']
# [0, 'dC']
# [0, 'U\\']
# [0, '<d']
# [0, 'J.']
# [0, '{\t']
# [0, 'D|']
# [0, 'k/']
# [0, 'qW']
# [0, 'Qq']
# [0, ';.']
# [0, 'I\r']
# [0, 'H"']
# [0, 'pq']
# [0, 'T~']
# [0, ':@']
# [0, ' S']
# [0, 'pA']
# [0, ',z']
# [1, 'Ta']
# [0, 'di']
# [0, '2l']
# [0, 'v@']
# [0, 'u3']
# [0, ')G']
# [0, 'M"']
# [0, '$z']
# [0, '\x0cy']
# [0, ':{']
# [0, 'n8']
# [0, '_(']
# [0, '\x0bw']
# [0, '$_']
# [0, ")'"]
# [0, 'by']
# [0, '0n']
# [0, 'g5']
# [0, "'R"]
# [0, 'ej']
# [0, 'sC']
# [0, 'S ']
# [0, 'k?']
# [0, 'y)']
# [0, 'A7']
# [0, '&4']
# [0, '^@']
# [0, '\tV']
# [0, '_T']
# [0, 'h7']
# [0, 'p*']
# [0, 'qo']
# [0, ' t']
# [0, '-%']
# [0, 'bq']
# [0, '^q']
# [0, '*K']
# [0, 'qR']
# [0, '5d']
# [0, 'Y\\']
# [0, '7n']
# [0, 'w^']
# [0, 'y?']
# [0, 'z|']
# [0, 'k"']
# [0, 'Nk']
# [0, ':X']
# [0, 'm4']
# [0, '\tT']
# [0, 'xk']
# [0, '\x0ct']
# [0, 'b:']
# [0, ':M']
# [0, 'c7']
# [0, 'CP']
# [0, 'Mn']
# [0, 'aQ']
# [0, '%;']
# [0, '"h']
# [0, 'hF']
# [0, 'I4']
# [0, 'Vo']
# [0, '"b']
# [0, 'r9']
# [0, 'E\x0c']
# [0, 'Am']
# [0, 'js']
# [0, '9+']
# [0, ';|']
# [0, '^R']
# [0, 'g/']
# [0, 'kv']
# [0, '2c']
# [0, 'gN']
# [0, ']P']
# [0, 'K\n']
# [0, '~C']
# [0, '3`']
# [0, 'tc']
# [0, '7M']
# [0, '[p']
# [0, '\'"']
# [0, '!\r']
# [0, '6:']
# [0, '!)']
# [0, 'q\\']
# [0, 'AO']
# [0, 'qP']
# [0, 'kU']
# [0, '@h']
# [0, 'BD']
# [0, 'Eo']
# [0, 'v:']
# [0, '@&']
# [0, ':N']
# [0, '#N']
# [0, '42']
# [0, ' ?']
# [0, '%8']
# [0, 'pY']
# [0, 'K}']
# [0, 'Zc']
# [0, 'BK']
# [0, 'Q5']
# [0, '\tj']
# [0, 'Rh']
# [0, '@c']
# [0, 'RV']
# [0, ' F']
# [0, 'n*']
# [0, 'o;']
# [0, 'Pl']
# [0, '|q']
# [0, '%N']
# [0, 'ES']
# [0, 'Fg']
# [0, 'mC']
# [0, 'PR']
# [0, 'Bp']
# [0, '-|']
# [0, '.o']
# [0, '0^']
# [0, '\n5']
# [0, 'L.']
# [0, ']M']
# [0, '>m']
# [0, '<`']
# [0, '= ']
# [0, 'y/']
# [0, 'Dn']
# [0, 'o?']
# [0, 'dP']
# [0, 'le']
# [0, '"m']
# [0, 'Tp']
# [0, '%E']
# [0, 'xd']
# [0, 'f#']
# [0, 'U-']
# [0, 'aR']
# [0, 'k ']
# [0, 'aJ']
# [0, '\x0cj']
# [0, '&I']
# [0, 'QJ']
# [0, '{2']
# [0, 'V>']
# [0, 'k.']
# [0, '4\x0c']
# [0, 'kq']
# [0, 'z3']
# [0, '\x0bK']
# [0, '&t']
# [0, '2d']
# [0, '{7']
# [0, 'm8']
# [0, '\n`']
# [0, '{>']
# [0, 'f!']
# [0, 'BJ']
# [0, 'yY']
# [0, '}b']
# [0, '!{']
# [0, ',>']
# [0, 'o@']
# [1, ':a']
# [0, 'G1']
# [0, '[|']
# [0, "'g"]
# [0, '8|']
# [0, '9}']
# [0, '?\\']
# [0, '\rx']
# [0, 'XO']
# [0, '=o']
# [0, ').']
# [1, '0a']
# [0, 't(']
# [0, 'Ij']
# [0, '=M']
# [0, 'qg']
# [0, 'pe']
# [0, 'ny']
# [0, '"\\']
# [0, '|i']
# [0, ':\\']
# [0, "b'"]
# [0, '3X']
# [0, '5)']
# [0, ']?']
# [1, '\ra']
# [0, '}`']
# [0, 'dh']
# [0, '+3']
# [0, '#r']
# [0, 'Gg']
# [0, 'PA']
# [0, 'Ly']
# [0, ',w']
# [0, '~&']
# [0, 'cC']
# [1, '1^']
# [0, '`O']
# [0, 'r{']
# [0, 'j,']
# [0, ';9']
# [0, '_x']
# [0, '&8']
# [0, 'VB']
# [0, '2g']
# [0, 'B0']
# [0, '=)']
# [0, 'Gp']
# [0, 'o#']
# [0, '`F']
# [0, "'F"]
# [0, '}n']
# [0, 'H8']
# [0, 'FA']
# [0, '<G']
# [0, '"{']
# [0, 'W>']
# [0, '%`']
# [0, '?u']
# [0, 'gv']
# [0, 'i%']
# [0, 'kJ']
# [0, 'jB']
# [0, '"p']
# [0, '{[']
# [0, 'Cm']
# [0, '&1']
# [0, 'gk']
# [0, 'N[']
# [0, '\n?']
# [0, '\r:']
# [0, ':%']
# [0, '%8']
# [0, '>7']
# [0, '2=']
# [0, 'l^']
# [0, '8\t']
# [0, 'k]']
# [0, '>t']
# [0, 'yi']
# [0, ':A']
# [0, 'mj']
# [0, 'VK']
# [0, '{:']
# [0, ':\t']
# [0, '5m']
# [0, '96']
# [0, 'PH']
# [0, 'yA']
# [0, 'a#']
# [0, 'M<']
# [0, '\tg']
# [0, 'm^']
# [0, 'Hw']
# [0, 'B\n']
# [0, "x'"]
# [0, 'hF']
# [0, 'h6']
# [0, 'By']
# [0, 'Z`']
# [0, '\nH']
# [0, '?\n']
# [0, 'jH']
# [0, 'bF']
# [0, 'xh']
# [0, '%$']
# [0, 'I}']
# [0, '/v']
# [0, 'P.']
# [0, '5\r']
# [0, '+?']
# [0, 'I,']
# [0, 'WM']
# [0, 'Pm']
# [0, 'fn']
# [0, 'Db']
# [0, '\x0bW']
# [0, '@?']
# [0, 'mS']
# [0, "'r"]
# [0, 'mU']
# [0, 'JI']
# [0, 'YL']
# [0, '3g']
# [0, '!f']
# [0, 'x(']
# [0, 'qO']
# [0, ')q']
# [0, '5+']
# [0, 'Wq']
# [0, '(y']
# [0, 'j5']
# [0, '<r']
# [0, ',\r']
# [0, 'p@']
# [0, 'iV']
# [0, ' !']
# [0, '2+']
# [0, 'Wi']
# [0, 'kB']
# [0, 'Qs']
# [0, '{7']
# [0, 'WD']
# [0, 'Cm']
# [0, '\n0']
# [0, ']y']
# [0, 'JM']
# [0, 'LY']
# [0, '\\X']
# [0, '\x0c$']
# [0, ']5']
# [0, 'UT']
# [0, 'cP']
# [1, ';a']
# [0, '*$']
# [0, 'GR']
# [0, 'j*']
# [0, '+=']
# [0, '\tq']
# [0, '4L']
# [0, 'f}']
# [0, ')s']
# [0, 'FO']
# [0, '\t.']
# [0, 'G6']
# [0, '+:']
# [0, 'HZ']
# [0, '#n']
# [0, '&+']
# [0, 'iI']
# [0, '6V']
# [0, 'zt']
# [0, 'qp']
# [0, '"$']
# [0, 'N0']
# [0, '#j']
# [0, '#q']
# [0, 'eI']
# [0, '`x']
# [0, '6}']
# [0, '!;']
# [0, '\t"']
# [0, 'eb']
# [0, '(V']
# [0, 'W]']
# [0, 'B\x0b']
# [0, ',;']
# [0, 'Z8']
# [0, '#\t']
# [0, 'r&']
# [0, 'wG']
# [0, 'A_']
# [0, '.0']
# [0, '+}']
# [0, '(<']
# [0, '|O']
# [0, 'Wt']
# [0, 'F%']
# [0, '\\$']
# [0, ']Q']
# [0, ',d']
# [0, 'Vn']
# [0, 'Oo']
# [0, 'mT']
# [0, 'FW']
# [0, 'm2']
# [0, 'XH']
# [0, 'S;']
# [0, 'E+']
# [0, 'Ih']
# [0, 'o~']
# [0, '\\(']
# [0, '"O']
# [0, 'qb']
# [0, 'F7']
# [0, 'M\r']
# [0, '\x0bu']
# [0, '09']
# [0, '{z']
# [0, 'j*']
# [0, '\\:']
# [1, '1|']
# [0, '[1']
# [0, '.Z']
# [0, ';c']
# [0, '&K']
# [0, '\x0cE']
# [0, 'Co']
# [0, 'C\\']
# [0, '9$']
# [0, 'tk']
# [0, 'FN']
# [0, 'gx']
# [0, '(b']
# [0, 'X^']
# [0, 'Ms']
# [0, '26']
# [0, 'R%']
# [0, '+J']
# [0, 'ed']
# [0, 'Jj']
# [0, '\\B']
# [0, 'w3']
# [0, '\tt']
# [0, '-\x0c']
# [0, '\tl']
# [0, 'y7']
# [0, 'V\n']
# [0, 'nb']
# [0, '49']
# [0, 'dh']
# [0, '>h']
# [0, '[l']
# [0, 'j{']
# [0, '%-']
# [0, '.!']
# [0, 'jc']
# [0, 'm[']
# [0, 'CG']
# [0, 'v ']
# [0, 'C\t']
# [0, '#B']
# [0, ';C']
# [0, 'H\\']
# [0, '=4']
# [0, '{9']
# [0, 'kW']
# [0, 'ap']
# [0, '8+']
# [0, 'P6']
# [0, '`6']
# [0, 'd/']
# [0, '-K']
# [0, 'xJ']
# [0, '[C']
# [0, '\\7']
# [0, 'wZ']
# [0, 'b<']
# [0, '3J']
# [0, '\x0c!']
# [0, 'C#']
# [0, '58']
# [0, 'R"']
# [0, "'o"]
# [0, '\nw']
# [0, 'QS']
# [0, '2T']
# [0, 'Q1']
# [0, 'c\r']
# [0, '\tR']
# [0, '-t']
# [0, '=m']
# [0, ')"']
# [0, 'e^']
# [0, 'cy']
# [0, '0Y']
# [0, 'N8']
# [0, '}B']
# [0, '!D']
# [0, 'N]']
# [0, 't<']
# [0, 'c(']
# [0, '0O']
# [0, 'g6']
# [0, '2 ']
# [0, 'pL']
# [0, '4\x0c']
# [0, '0\r']
# [0, 'L)']
# [0, '\n\r']
# [0, '0y']
# [0, '(:']
# [0, '>U']
# [0, 'z\r']
# [0, '\x0c[']
# [0, '?*']
# [0, '"^']
# [0, '8j']
# [0, 'f2']
# [0, '/D']
# [0, "'<"]
# [0, '9g']
# [0, 'eE']
# [0, '{\r']
# [0, 'pf']
# [0, 'N!']
# [0, 'i{']
# [0, 'lJ']
# [0, 'Uq']
# [0, 'XU']
# [0, '@H']
# [0, '7t']
# [0, 'R>']
# [0, 'J\x0b']
# [2, '1a']

# %% [markdown]
# ## 6. Un número estrobogramático, es un número que es rotacionalmente simétrico, de modo que se ve igual cuando se gira 180 grados. Por ejemplo: 69, 96, 1001, etc. Los números 69 y 96 tienen dos dígitos, por lo que diremos que son números estrobogramáticos de longitud dos y el 1001 es de longitud cuatro. Escribe una función que calcule los números estrobogramáticos de longitud n. La función debe recibir como argumento la variable n y debe de regresar una lista con todos los números estrobogramáticos de longitud n.
# Hint: Usa recursión con la longitud de los números.

# %%
def estrobogramatico_numero(elemento):
    pares1 = ["1","6","8","9","0"]
    pares2 = ["1","9","8","6","0"]
    elemento_arreglo = str(elemento)
    elemento_reflejado = elemento_arreglo[::-1]
    contador = 0
    for i in range(0,len(elemento_arreglo)):
        for j in range(0,5):
            if elemento_arreglo[i]==pares1[j] and elemento_reflejado[i] == pares2[j] :
                contador +=1
        
    if contador == len(elemento_arreglo):
        return True
    else:
        return False

# %%
def estrobogramatico(n):
    lista=[]
    for i in range(10**(n-1),(10**n)):
        if estrobogramatico_numero(i) ==True:
            lista.append(i)
    return lista

# %%
print(estrobogramatico(3))
# Out:
# [101, 111, 181, 609, 619, 689, 808, 818, 888, 906, 916, 986]

# %% [markdown]
# ### 7. Simular el lanzamiento de un dado para calcular la probabilidad frecuencial.
#
# - Escribe una función que simule el experimento de lanzar un dado, los posibles valores a obtener son: 1,2,3,4,5 o 6.

# %%
def valor_dado():
    return random.randint(1, 6)

# %%
##Probando la función
valor_dado()

# %% [markdown]
# - Escribe una función que realice n simulaciones del lanzamiento de un dado y compruebe experimentalmente que el número de veces que aparece una de las caras entre el total de lanzamientos (n) se aproxima a 1/6 conforme n crece. La función debe generar un archivo de texto donde cada renglón contenga los datos de cada lanzamiento. Los datos a escribir son: número de simulación, resultado obtenido y los cocientes $n_c/i$, donde $n_c$ es la cantidad de veces cayó la cara $c \in \{1, 2, 3, 4, 5, 6\}$ e $i$ es la cantidad de lanzamientos realizados hasta el momento.

# %%
def valor_dadon_1(n):
    #Creamos una lista que enumere las N tiradas
    valores = [1,2,3,4,5,6]
    #Arreglo que señale el número de tiradas hasta el i-ésimo momento
    numero=[i for i in range(1,n+1)]
    #Lista donde se guardará el cociente
    cociente=np.zeros((n,6))
    #lista donde se anexarán los conteos de los resultados
    resultados = np.zeros((n,6))
    #Creamos los elementos para cada lista en la primera tirada
    k = random.randint(1, 6)
    resultados[0,k-1]=1
    cociente[0,k-1]=1
            
    for i in range(1,n):
        #tiramos los dados y obtenemos el valor
        k = random.randint(1, 6)
        #anexamos el valor
        resultados[i,k-1] = resultados[i-1,k-1] + 1
        cociente[i,k-1] = resultados[i,k-1]/i
        j=0
        if j!=k:
            resultados[i,j-1] = resultados[i-1,j-1]
            j +=1
            cociente[i,j-1] = resultados[i,j-1]/i
        else:
            j += 1
        
    return [numero, resultados, cociente]

# %%
def valor_dadon(n):
    #Cifras significativas:
    cifras = 2
    #Creamos una lista que enumere las N tiradas
    valores = [1,2,3,4,5,6]
    #Arreglo que señale el número de tiradas, los conteos caras 1 al 6 y el cociente de cada cara 1 al 6 
    RESULTADOS = np.zeros((n,1+6+6))
    #Primeros valores
    #Define la primer tirada
    RESULTADOS[0,0]=int(1)
    #Resultado de la primera tirada
    k = int(random.randint(1, 6))
    #
    RESULTADOS[0,k] = int(1)
    RESULTADOS[0,k+6] = int(1)
    for i in range(1,n):
        RESULTADOS[i,0] = int(i+1)
        k = int(random.randint(1, 6))
        RESULTADOS[i,k] = int(1 + RESULTADOS[i-1,k])
        RESULTADOS[i,k+6] = round(RESULTADOS[i,k]/(i+1),cifras)
        
        for j in valores:
            if j!=k:
                RESULTADOS[i,j] = int(RESULTADOS[i-1,j])
                RESULTADOS[i,j+6] = round(RESULTADOS[i-1,j]/(i+1),cifras)    
    return RESULTADOS

# %%
print(" , ".join(str(x) for x in resultados[1,:]))

# %%
resultados2 = valor_dadon(15)
resultados_cadena = []
for i in range(0,10):
    obj=" , ".join(str(x) for x in resultados2[i,:])
    resultados_cadena.append(obj)

print(resultados_cadena[9])

# %%
print(np.read.np.savetxt('matriz00.txt',resultados2))

# %%
#Ahora la función que nos devuelva texto
def valor_dadon_txt(n):
    #Creamos una lista que enumere las N tiradas
    valores = [1,2,3,4,5,6]
    #Arreglo que señale el número de tiradas, los conteos caras 1 al 6 y el cociente de cada cara 1 al 6 
    RESULTADOS = np.zeros((n,1+6+6))
    #Primeros valores
    #Define la primer tirada
    RESULTADOS[0,0]=1
    #Resultado de la primera tirada
    k = random.randint(1, 6)
    #
    RESULTADOS[0,k] = 1
    RESULTADOS[0,k+6] = 1
    for i in range(1,n):
        RESULTADOS[i,0] = int(i+1)
        k = random.randint(1, 6)
        RESULTADOS[i,k] = 1 + RESULTADOS[i-1,k]
        RESULTADOS[i,k+6] = RESULTADOS[i,k]/(i+1)
        
        for j in valores:
            if j!=k:
                RESULTADOS[i,j] = RESULTADOS[i-1,j]
                RESULTADOS[i,j+6] = RESULTADOS[i-1,j]/(i+1)    
    ARCHIVO = np.savetxt('simulación.txt',RESULTADOS,delimiter=' ',fmt='%.3e',header=
                         'DATOS: Tirada, Conteo de: 1,2,3,4,5,6, Frecuencia: 1/tirada, 2/tirada, 3/tirada,4/tirada, 5/tirada, 6/tirada')
    return ARCHIVO

# %%
#Probando la función
valor_dadon_txt(200)

# %% [markdown]
# # Problema 8
#
# Dada la lista ordenada [2, 5, 6, 8, 9, 10], una rotación es tomar el último elemento y desplazarlo al inicio de la lista quedando [10, 2, 5, 6, 8, 9]. Por ejemplo: la lista [8, 9, 10, 2, 5, 6] fue rotada 3 veces. Dada una lista rotada k veces, escribe una función que calcule el valor de $k$, es decir la cantidad de rotaciones o desplazamientos realizados a la lista. Puedes suponer que la lista no tiene elementos repetidos.

# %%
#lista1 lista sin rota
#lista2 lista  rotada
def num_rotaciones(lista1,lista2):
    primero = lista1[0]
    k = 0
    for i in lista2:
        if i == primero:
            print(k)
        else:
            k +=1

# %%
print(num_rotaciones([1,2,3],[2,3,1]))
# Out:
# 2
# None

# %% [markdown]
# # Problema 9
#
# Una forma de aproximar $\pi$ dada la sección ubicada en el primer cuadrante del circulo unitario.
#
# Escribe una función que genere los valores pseudoaleatorios (x,y) con distribución uniforme dentro del intervalo (0, 1), independiente un valor del otro. Si se tiene que $y \leq \sqrt{1 − x^2}$, entonces el punto (x,y) está dentro del cuarto de círculo. En caso contrario se considera un fracaso. Así, al repetir varias veces este procedimiento, el cociente del número de éxitos $n_E$ entre el número de ensayos $n$ será una aproximación del área de la región. Siendo una cuarta parte del círculo unitario, su área es $\pi/4$. La función recibe como argumento el valor de $n$ y debe regresar el valor de la aproximación de $\pi$. Para este ejercicio puedes utilizar la función uniform del modulo random de Python.

# %%
def pi(n):
    num_exitos = 0
    for i in range(0,n):
        valor = [random.uniform(0, 1),random.uniform(0, 1)]
        if (valor[1]**2+valor[0]**2)<=1:
            num_exitos +=1
    cociente = num_exitos/n
    return cociente*4

# %%
print(pi(100000))
# Out:
# 3.13864

# %%
#ya es una buena aproximación
